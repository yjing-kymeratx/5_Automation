# %%
# !mmpdb generate --smiles 'CCN(C)C(=O)C1=CC2=C(N1)C(F)=CN=C2C1=C(Cl)C=C(N2CCC(CN3CCN(C4=CC=CC5=C4N(C)C(=O)N5C4CCC(=O)NC4=O)CC3)CC2)C=C1' ./results/Compounds_All.mmpdb
# Out:
# start	constant	from_smiles	to_smiles	r	pseudosmiles	final	heavies_diff	#pairs	pair_from_id	pair_from_smiles	pair_to_id	pair_to_smiles
# CCN(C)C(=O)c1cc2c(-c3ccc(N4CCC(CN5CCN(c6cccc7c6n(C)c(=O)n7C6CCC(=O)NC6=O)CC5)CC4)cc3Cl)ncc(F)c2[nH]1	*N(C)C(=O)c1cc2c(-c3ccc(N4CCC(CN5CCN(c6cccc7c6n(C)c(=O)n7C6CCC(=O)NC6=O)CC5)CC4)cc3Cl)ncc(F)c2[nH]1	[*:1]CC	[*:1]C	0	[*:1](~*)	CN(C)C(=O)c1cc2c(-c3ccc(N4CCC(CN5CCN(c6cccc7c6n(C)c(=O)n7C6CCC(=O)NC6=O)CC5)CC4)cc3Cl)ncc(F)c2[nH]1	-1	17	KT-0345026	CCN(CC)C(=O)NC1CCN(C(=O)c2cc(Cl)c[nH]2)CC1	KT-0345006	CCN(C)C(=O)NC1CCN(C(=O)c2cc(Cl)c[nH]2)CC1
# CCN(C)C(=O)c1cc2c(-c3ccc(N4CCC(CN5CCN(c6cccc7c6n(C)c(=O)n7C6CCC(=O)NC6=O)CC5)CC4)cc3Cl)ncc(F)c2[nH]1	*N(C)C(=O)c1cc2c(-c3ccc(N4CCC(CN5CCN(c6cccc7c6n(C)c(=O)n7C6CCC(=O)NC6=O)CC5)CC4)cc3Cl)ncc(F)c2[nH]1	[*:1]CC	[*:1][H]	0	[*:1](~*)	CNC(=O)c1cc2c(-c3ccc(N4CCC(CN5CCN(c6cccc7c6n(C)c(=O)n7C6CCC(=O)NC6=O)CC5)CC4)cc3Cl)ncc(F)c2[nH]1	-2	7	KT-0335631	CCC1CCCCN1C(=O)c1cc(Cl)c[nH]1	KT-0344963	O=C(c1cc(Cl)c[nH]1)N1CCCCC1
# ...

# %%
# mmpdb transform --smiles 'c1cccnc1O' test_data.mmpdb --property MP
# !mmpdb transform --smiles 'CCN(C)C(=O)C1=CC2=C(N1)C(F)=CN=C2C1=C(Cl)C=C(N2CCC(CN3CCN(C4=CC=CC5=C4N(C)C(=O)N5C4CCC(=O)NC4=O)CC3)CC2)C=C1' ./results/Compounds_All.mmpdb --property bpKa1
# Out:
# ID	SMILES	bpKa1_from_smiles	bpKa1_to_smiles	bpKa1_radius	bpKa1_smarts	bpKa1_pseudosmiles	bpKa1_rule_environment_id	bpKa1_count	bpKa1_avg	bpKa1_std	bpKa1_kurtosis	bpKa1_skewness	bpKa1_min	bpKa1_q1	bpKa1_median	bpKa1_q3	bpKa1_max	bpKa1_paired_t	bpKa1_p_value
# 1	C#CCN(CC)C(=O)c1cc2c(-c3ccc(N4CCC(CN5CCN(c6cccc7c6n(C)c(=O)n7C6CCC(=O)NC6=O)CC5)CC4)cc3Cl)ncc(F)c2[nH]1	[*:1]C	[*:1]CC#C	0	[#0;X1;H0;+0;!R:1]	[*:1](~*)	382813	1	0				0	0	0	0	0
# 2	C#CCOc1cnc(-c2ccc(N3CCC(CN4CCN(c5cccc6c5n(C)c(=O)n6C5CCC(=O)NC5=O)CC4)CC3)cc2Cl)c2cc(C(=O)N(C)CC)[nH]c12	[*:1]F	[*:1]OCC#C	2	[#0;X1;H0;+0;!R:1]-[#6;X3;H0;+0;R](:[#6;X3;H0;+0;R]):[#6;X3;H1;+0;R]	[*:1]-[c](:[c](~*)(~*)):[cH](~*)	483081	1	0				0	0	0	0	0
# 3	C#CCn1c(=O)n(C2CCC(=O)NC2=O)c2cccc(N3CCN(CC4CCN(c5ccc(-c6ncc(F)c7[nH]c(C(=O)N(C)CC)cc67)c(Cl)c5)CC4)CC3)c21	[*:1]C	[*:1]CC#C	0	[#0;X1;H0;+0;!R:1]	[*:1](~*)	382813	1	0				0	0	0	0	0
# ...

# %%
# !mmpdb transform --smiles 'CCN(C)C(=O)C1=CC2=C(N1)C(F)=CN=C2C1=C(Cl)C=C(N2CCC(CN3CCN(C4=CC=CC5=C4N(C)C(=O)N5C4CCC(=O)NC4=O)CC3)CC2)C=C1' ./results/Compounds_All.mmpdb --property Bioavailability -r 0
# Out:
# ID	SMILES	Bioavailability_from_smiles	Bioavailability_to_smiles	Bioavailability_radius	Bioavailability_smarts	Bioavailability_pseudosmiles	Bioavailability_rule_environment_id	Bioavailability_count	Bioavailability_avg	Bioavailability_std	Bioavailability_kurtosis	Bioavailability_skewness	Bioavailability_min	Bioavailability_q1	Bioavailability_median	Bioavailability_q3	Bioavailability_max	Bioavailability_paired_t	Bioavailability_p_value
# 1	CCN(C)C(=O)c1cc2c(-c3ccc(C4CC(CN5CCN(c6cccc7c6n(C)c(=O)n7C6CCC(=O)NC6=O)CC5)C4)cc3Cl)ncc(F)c2[nH]1	[*:1]C1CCN([*:2])CC1	[*:1]C1CC([*:2])C1	0	[#0;X1;H0;+0;!R:1].[#0;X1;H0;+0;!R:2]	[*:1](~*).[*:2](~*)	248298	1	3.3				3.3	3.3	3.3	3.3	3.3
# 2	CCN(C)C(=O)c1cc2c(-c3ccc(N4CC(CN5CCN(c6cccc7c6n(C)c(=O)n7C6CCC(=O)NC6=O)CC5)C4)cc3Cl)ncc(F)c2[nH]1	[*:1]C1CCN([*:2])CC1	[*:1]C1CN([*:2])C1	0	[#0;X1;H0;+0;!R:1].[#0;X1;H0;+0;!R:2]	[*:1](~*).[*:2](~*)	148738	1	-6.11				-6.11	-6.11	-6.11	-6.11	-6.11
# ...
