# %%
import warnings
warnings.filterwarnings('ignore')

import os
import chardet
import numpy as np
import pandas as pd

# %%
def determine_encoding(dataFile):
    # Step 1: Open the CSV file in binary mode
    with open(dataFile, 'rb') as f:
        data = f.read()
    
    # Step 2: Detect the encoding using the chardet library
    encoding_result = chardet.detect(data)

    # Step 3: Retrieve the encoding information
    encoding = encoding_result['encoding']

    # Step 4: Print/export the detected encoding information
    # print("Detected Encoding:", encoding)
    return encoding

# %%
dataFile = f'./DataView_ADMET_4_MMP_1__export.csv'
encoding = determine_encoding(dataFile)

dataTable = pd.read_csv(dataFile, encoding=encoding)
dataTable.head(3)
# Out:
#   Compound Name                                          Structure  \
# 0    KT-0194988  C3(CCN(C(=O)c1cc(c(c(c1)N2CCC(=O)NC2=O)Cl)C)CC...
# 1    KT-0194990  N1(CCC(=O)NC1=O)c2cc(cc(c2C)Cl)C(=O)N%11CCC%10...
# 2    KT-0194991  CNc1cc(nn2c(cnc21)C(=O)N[C@H]3[C@H](OC)CC3)N5c...
#
#   Concat;Project      Concat;External Id  \
# 0           TYK2  PH-CMR-TK2-2575-0N-001
# 1           TYK2  PH-CMR-TK2-2610-0N-001
# 2           TYK2  PH-CMR-TK2-2615-0N-001
#
#   ADME MDCK(WT) Permeability;Mean;A to B Papp (10^-6 cm/s);(Mod)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ADME MDCK(WT) Permeability;Mean;A to B Papp (10^-6 cm/s);(Num)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   ADME MDCK(WT) Permeability;Mean;B to A Papp (10^-6 cm/s);(Mod)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ADME MDCK(WT) Permeability;Mean;B to A Papp (10^-6 cm/s);(Num)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   ADME MDCK(WT) Permeability;Concat;Comments  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
#
#   ADME MDCK(WT) Permeability;Concat;Run Date  ...  \
# 0                                        NaN  ...
# 1                                        NaN  ...
# 2                                        NaN  ...
#
#    ADME Tox-manual patch hERG 34C;Mean;Average % of hERG inhibition;(Mod)  \
# 0                                                  =
# 1                                                  =
# 2                                                  =
#
#    ADME Tox-manual patch hERG 34C;Mean;Average % of hERG inhibition;(Num)  \
# 0                                          14.741188
# 1                                          18.038312
# 2                                          17.836152
#
#   ADME Tox-manual patch hERG 34C;Concat;Comments  \
# 0                 21.36% inhibition @ 3 ?M; ; ;
# 1                 24.47% inhibition @ 3 ?M; ; ;
# 2                                            NaN
#
#    ADME Tox-manual patch hERG 34C;Mean;Concentration (uM);(Mod)  \
# 0                                                  =
# 1                                                  =
# 2                                                  =
#
#   ADME Tox-manual patch hERG 34C;Mean;Concentration (uM);(Num)  \
# 0                                           1.433333
# 1                                           1.433333
# 2                                           1.433333
#
#    ADME Tox-manual patch hERG 34C;Concat;Date run  \
# 0         5/21/2024;5/21/2024;5/21/2024;5/21/2024
# 1         5/21/2024;5/21/2024;5/21/2024;5/21/2024
# 2         5/21/2024;5/21/2024;5/21/2024;5/21/2024
#
#   ADME Tox-manual patch hERG 34C;GMean;m-patch hERG IC50 [uM];(Mod)  \
# 0                                                  >
# 1                                                  >
# 2                                                  =
#
#   ADME Tox-manual patch hERG 34C;GMean;m-patch hERG IC50 [uM];(Num)  \
# 0                                            3.00000
# 1                                            3.00000
# 2                                            5.19295
#
#    ADME Tox-manual patch hERG 34C;Mean;SD;(Mod)  \
# 0                                             =
# 1                                             =
# 2                                             =
#
#   ADME Tox-manual patch hERG 34C;Mean;SD;(Num)
# 0                                     0.467074
# 1                                     1.265248
# 2                                     4.445823
#
# [3 rows x 40 columns]

# %%
def extractPropertyDataFromD360Table(row, colName_mod, colName_num):
    result = np.nan
    if colName_mod in row and colName_num in row:
        if row.notna()[colName_mod] and row.notna()[colName_num]:
            if row[colName_mod] == '=':
                result = row[colName_num]
    return result

def calc_mean(value_list):
    value_list_clean = []
    for v in value_list:
        if v not in [None, np.nan, '', ' ']:
            try:
                v_num = float(v)
            except Exception as e:
                print(f'Error, cannot numericalize value {v}', e)
            else:
                value_list_clean.append(v_num)
    return np.mean(value_list_clean)

def calc_eIC50_hERG(comments_str):
    # e.g., comments_str = '21.38% inhibition @ 10 ?M'
    try:
        [str_inhb, str_conc] = comments_str.split('@')
        inhb = float(str_inhb.split('%')[0])
        inhb = 0.1 if inhb < 0 else (99.99 if inhb > 100 else inhb)
        conc = float(str_conc.split('M')[0][:-1])
        eIC50 = conc*(100-inhb)/inhb
    except Exception as e:
        eIC50 = None
        if comments_str not in [' ', '/']:
            print(f'Error, cannot calc hERG eIC50 from comment data. {comments_str}')
    return eIC50

def calc_EstFa(PKF_PO, Clobs_IV, Species='Rat'):
    dict_IV_ratio = {'Rat': 90, 'Mouse': 70, 'Dog': 30, 'Monkey': 44}    
    try:
        estfa = (PKF_PO/100)/(1-(Clobs_IV/dict_IV_ratio[Species]))
    except Exception as e:
        estfa = np.nan
    return estfa

#########################################################################################
def clean_up_permeability(row):
    colName_prefix = 'ADME MDCK(WT) Permeability'
    # colName_a2b_rec = colName_prefix + ';Mean;' + 'A to B Recovery (%)' 
    colName_a2b_mod = colName_prefix + ';Mean;' + 'A to B Papp (10^-6 cm/s);(Mod)'
    colName_a2b_num = colName_prefix + ';Mean;' + 'A to B Papp (10^-6 cm/s);(Num)'
    permeability = extractPropertyDataFromD360Table(row, colName_a2b_mod, colName_a2b_num)
    return permeability

def clean_up_efflux(row):
    colName_prefix = 'ADME MDCK (MDR1) efflux'
    # colName_a2b_mod = colName_prefix + ';Mean;' + 'A to B Papp (10^-6 cm/s);(Mod)'
    # colName_a2b_num = colName_prefix + ';Mean;' + 'A to B Papp (10^-6 cm/s);(Num)'
    # colName_a2b_rec = colName_prefix + ';Mean;' + 'A to B Recovery (%)'
    # colName_b2a_mod = colName_prefix + ';Mean;' + 'B to A Papp (10^-6 cm/s);(Mod)'
    # colName_b2a_num = colName_prefix + ';Mean;' + 'B to A Papp (10^-6 cm/s);(Num)'
    # colName_b2a_rec = colName_prefix + ';Mean;' + 'B to A Recovery (%)'
    # colName_comments = colName_prefix + ';Concat;' + 'Comments'
    colName_efflux_mod = colName_prefix + ';Mean;' + 'Efflux Ratio;(Mod)'
    colName_efflux_num = colName_prefix + ';Mean;' + 'Efflux Ratio;(Num)'
    efflux = extractPropertyDataFromD360Table(row, colName_efflux_mod, colName_efflux_num)
    return efflux

def clean_up_hERG(row, eIC50=False):
    colName_prefix = 'ADME Tox-manual patch hERG 34C'
    # colName_hERG_date = colName_prefix + ';Concat;' + 'Date run'
    # colName_sd_mod = colName_prefix + ';GMean;' + 'SD;(Mod)'
    # colName_sd_num = colName_prefix + ';GMean;' + 'SD;(Num)'

    ## expt IC50
    colName_ic50_mod = colName_prefix + ';GMean;' + 'm-patch hERG IC50 [uM];(Mod)'
    colName_ic50_num = colName_prefix + ';GMean;' + 'm-patch hERG IC50 [uM];(Num)'
    hERG_IC50 = extractPropertyDataFromD360Table(row, colName_ic50_mod, colName_ic50_num)

    ## estimated IC50 by comments column
    if eIC50:
        colName_hERG_cmnt = colName_prefix + ';Concat;' + 'Comments'
        hERG_eIC50_list = []
        if colName_hERG_cmnt in row:
            if row.notna()[colName_hERG_cmnt]:
                for cmnt in row[colName_hERG_cmnt].split(';'):
                    hERG_eIC50_list.append(calc_eIC50_hERG(cmnt))    
        hERG_eIC50 = calc_mean(hERG_eIC50_list)

        ## determine mixedIC50
        if not np.isnan(hERG_IC50):
            hERG_mixedIC50, ambitiousData = hERG_IC50, 0
        elif not np.isnan(hERG_eIC50):
            hERG_mixedIC50, ambitiousData = hERG_eIC50, 1
        else:
            hERG_mixedIC50, ambitiousData = np.nan, np.nan
        return pd.Series([hERG_IC50, hERG_eIC50, hERG_mixedIC50, ambitiousData])
    else:
        return hERG_IC50

def clean_up_PK(row, Species='Rat', EstFa=False):
    colName_PKF_mod = f'ADME PK;Mean;F %;Dose: 10.000 (mg/kg);Route of Administration: PO;Species: {Species};(Mod)'
    colName_PKF_num = f'ADME PK;Mean;F %;Dose: 10.000 (mg/kg);Route of Administration: PO;Species: {Species};(Num)'
    PKF_PO = extractPropertyDataFromD360Table(row, colName_PKF_mod, colName_PKF_num)

    if EstFa:
        colName_Cl_mod = f'Copy 1 ;ADME PK;Mean;Cl_obs(mL/min/kg);Dose: 2.000 (mg/kg);Route of Administration: IV;Species: {Species};(Mod)'
        colName_Cl_num = f'Copy 1 ;ADME PK;Mean;Cl_obs(mL/min/kg);Dose: 2.000 (mg/kg);Route of Administration: IV;Species: {Species};(Num)'
        Clobs_IV = extractPropertyDataFromD360Table(row, colName_Cl_mod, colName_Cl_num)
        EstFa = calc_EstFa(PKF_PO, Clobs_IV)
        return pd.Series([PKF_PO, EstFa])
    else:
        return PKF_PO
    
#########################################################################################
Species = 'Rat'
dataTable[[f'F%_{Species}', f'EstFa_{Species}']] = dataTable.apply(lambda row: clean_up_PK(row, Species=Species, EstFa=True), axis=1)
dataTable['permeability'] = dataTable.apply(lambda row: clean_up_permeability(row), axis=1)
dataTable['efflux'] = dataTable.apply(lambda row: clean_up_efflux(row), axis=1)
dataTable[['hERG_IC50', 'hERG_eIC50', 'hERG_mixedIC50', 'ambitiousData']] = dataTable.apply(lambda row: clean_up_hERG(row, eIC50=True), axis=1)

# %%
# dataTable.to_csv(f'Data_ADMET_4_MMP.csv', index=False)
dataTable
# Out:
#      Compound Name                                          Structure  \
# 0       KT-0194988  C3(CCN(C(=O)c1cc(c(c(c1)N2CCC(=O)NC2=O)Cl)C)CC...
# 1       KT-0194990  N1(CCC(=O)NC1=O)c2cc(cc(c2C)Cl)C(=O)N%11CCC%10...
# 2       KT-0194991  CNc1cc(nn2c(cnc21)C(=O)N[C@H]3[C@H](OC)CC3)N5c...
# 3       KT-0194992  CNc1cc(nn2c(cnc21)C(=O)N[C@H]3[C@H](OC)CC3)N5c...
# 4       KT-0194993  CO[C@@H]1CC[C@H]1NC(=O)c2cnc3n2nc(cc3NC)N5CCc4...
# ...            ...                                                ...
# 6145    KT-0199163  n1(nc(c2c1ccc(c2)-c3ccc(cc3)N4C=NN(C4=O)C)C(=O...
# 6146    KT-0199164  Fc3c1c(n(nc1C(=O)Nc2cc(ccc2)C(=O)N)C)ccc3-c4cc...
# 6147    KT-0199167  N1(N=CN(C1=O)c2ccc(cc2)-c3cc(c(cc3)C)N4CCN(C4=...
# 6148    KT-0199168  Fc1c(cccc1-c2ccc(cc2)N3C=NN(C3=O)C)N4CCN(C4=O)...
# 6149    KT-0013395  FC1(F)CN(CCC1OCC#Cc2cccc3c2N(C)C(=O)N3C4CCC(=O...
#
#      Concat;Project                             Concat;External Id  \
# 0              TYK2                         PH-CMR-TK2-2575-0N-001
# 1              TYK2                         PH-CMR-TK2-2610-0N-001
# 2              TYK2                         PH-CMR-TK2-2615-0N-001
# 3              TYK2                         PH-CMR-TK2-2616-0N-001
# 4              TYK2  PH-CMR-TK2-2618-0N-001;PH-CMR-TK2-2618-0N-002
# ...             ...                                            ...
# 6145         STAT-6                                ST6-S-3601-001F
# 6146         STAT-6                                ST6-S-3602-001N
# 6147         STAT-6                                ST6-S-3607-001F
# 6148         STAT-6                                ST6-S-3611-001N
# 6149          IRAK4                                IRW-O-2959-001F
#
#      ADME MDCK(WT) Permeability;Mean;A to B Papp (10^-6 cm/s);(Mod)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6145                                                NaN
# 6146                                                NaN
# 6147                                                NaN
# 6148                                                NaN
# 6149                                                NaN
#
#       ADME MDCK(WT) Permeability;Mean;A to B Papp (10^-6 cm/s);(Num)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6145                                                NaN
# 6146                                                NaN
# 6147                                                NaN
# 6148                                                NaN
# 6149                                                NaN
#
#      ADME MDCK(WT) Permeability;Mean;B to A Papp (10^-6 cm/s);(Mod)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6145                                                NaN
# 6146                                                NaN
# 6147                                                NaN
# 6148                                                NaN
# 6149                                                NaN
#
#       ADME MDCK(WT) Permeability;Mean;B to A Papp (10^-6 cm/s);(Num)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6145                                                NaN
# 6146                                                NaN
# 6147                                                NaN
# 6148                                                NaN
# 6149                                                NaN
#
#      ADME MDCK(WT) Permeability;Concat;Comments  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 6145                                        NaN
# 6146                                        NaN
# 6147                                        NaN
# 6148                                        NaN
# 6149                                        NaN
#
#      ADME MDCK(WT) Permeability;Concat;Run Date  ...  \
# 0                                           NaN  ...
# 1                                           NaN  ...
# 2                                           NaN  ...
# 3                                           NaN  ...
# 4                                           NaN  ...
# ...                                         ...  ...
# 6145                                        NaN  ...
# 6146                                        NaN  ...
# 6147                                        NaN  ...
# 6148                                        NaN  ...
# 6149                                        NaN  ...
#
#       ADME Tox-manual patch hERG 34C;Mean;SD;(Mod)  \
# 0                                                =
# 1                                                =
# 2                                                =
# 3                                                =
# 4                                                =
# ...                                            ...
# 6145                                           NaN
# 6146                                           NaN
# 6147                                           NaN
# 6148                                           NaN
# 6149                                           NaN
#
#       ADME Tox-manual patch hERG 34C;Mean;SD;(Num) F%_Rat  EstFa_Rat  \
# 0                                         0.467074  10.80   0.125258
# 1                                         1.265248   3.87   0.048645
# 2                                         4.445823    NaN        NaN
# 3                                         1.646552    NaN        NaN
# 4                                         2.719742   7.30   0.104952
# ...                                            ...    ...        ...
# 6145                                           NaN   3.00   0.030241
# 6146                                           NaN   2.40   0.024432
# 6147                                           NaN  27.40   0.305652
# 6148                                           NaN   1.08   0.011823
# 6149                                           NaN    NaN        NaN
#
#      permeability  efflux hERG_IC50 hERG_eIC50  hERG_mixedIC50 ambitiousData
# 0             NaN     NaN       NaN  11.044944       11.044944           1.0
# 1             NaN     NaN       NaN   9.259910        9.259910           1.0
# 2             NaN     NaN   5.19295        NaN        5.192950           0.0
# 3             NaN     NaN   3.22913        NaN        3.229130           0.0
# 4             NaN     NaN       NaN  16.841270       16.841270           1.0
# ...           ...     ...       ...        ...             ...           ...
# 6145          NaN     NaN       NaN        NaN             NaN           NaN
# 6146          NaN     NaN       NaN        NaN             NaN           NaN
# 6147          NaN     NaN       NaN        NaN             NaN           NaN
# 6148          NaN     NaN       NaN        NaN             NaN           NaN
# 6149          NaN     NaN       NaN        NaN             NaN           NaN
#
# [6150 rows x 48 columns]

# %%
dataTable[dataTable['EstFa_Rat'].notna()]
# Out:
#      Compound Name                                          Structure  \
# 0       KT-0194988  C3(CCN(C(=O)c1cc(c(c(c1)N2CCC(=O)NC2=O)Cl)C)CC...
# 1       KT-0194990  N1(CCC(=O)NC1=O)c2cc(cc(c2C)Cl)C(=O)N%11CCC%10...
# 4       KT-0194993  CO[C@@H]1CC[C@H]1NC(=O)c2cnc3n2nc(cc3NC)N5CCc4...
# 5       KT-0194995  CO[C@@H]1CC[C@H]1NC(=O)c2cnc3n2nc(cc3NC)N5CCc4...
# 6       KT-0194996  CNc1cc(nn2c(cnc21)C(=O)N[C@H]3[C@H](OC)CC3)N5c...
# ...            ...                                                ...
# 6144    KT-0199157  Fc3c1c(n(cc1C(=O)Nc2cc(ccc2)C(=O)N)C)ccc3-c4c(...
# 6145    KT-0199163  n1(nc(c2c1ccc(c2)-c3ccc(cc3)N4C=NN(C4=O)C)C(=O...
# 6146    KT-0199164  Fc3c1c(n(nc1C(=O)Nc2cc(ccc2)C(=O)N)C)ccc3-c4cc...
# 6147    KT-0199167  N1(N=CN(C1=O)c2ccc(cc2)-c3cc(c(cc3)C)N4CCN(C4=...
# 6148    KT-0199168  Fc1c(cccc1-c2ccc(cc2)N3C=NN(C3=O)C)N4CCN(C4=O)...
#
#      Concat;Project                             Concat;External Id  \
# 0              TYK2                         PH-CMR-TK2-2575-0N-001
# 1              TYK2                         PH-CMR-TK2-2610-0N-001
# 4              TYK2  PH-CMR-TK2-2618-0N-001;PH-CMR-TK2-2618-0N-002
# 5              TYK2  PH-CMR-TK2-2620-0N-001;PH-CMR-TK2-2620-0N-002
# 6              TYK2                         PH-CMR-TK2-2621-0N-001
# ...             ...                                            ...
# 6144         STAT-6                                ST6-S-3517-001F
# 6145         STAT-6                                ST6-S-3601-001F
# 6146         STAT-6                                ST6-S-3602-001N
# 6147         STAT-6                                ST6-S-3607-001F
# 6148         STAT-6                                ST6-S-3611-001N
#
#      ADME MDCK(WT) Permeability;Mean;A to B Papp (10^-6 cm/s);(Mod)  \
# 0                                                   NaN
# 1                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 6144                                                NaN
# 6145                                                NaN
# 6146                                                NaN
# 6147                                                NaN
# 6148                                                NaN
#
#       ADME MDCK(WT) Permeability;Mean;A to B Papp (10^-6 cm/s);(Num)  \
# 0                                                   NaN
# 1                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 6144                                                NaN
# 6145                                                NaN
# 6146                                                NaN
# 6147                                                NaN
# 6148                                                NaN
#
#      ADME MDCK(WT) Permeability;Mean;B to A Papp (10^-6 cm/s);(Mod)  \
# 0                                                   NaN
# 1                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 6144                                                NaN
# 6145                                                NaN
# 6146                                                NaN
# 6147                                                NaN
# 6148                                                NaN
#
#       ADME MDCK(WT) Permeability;Mean;B to A Papp (10^-6 cm/s);(Num)  \
# 0                                                   NaN
# 1                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 6144                                                NaN
# 6145                                                NaN
# 6146                                                NaN
# 6147                                                NaN
# 6148                                                NaN
#
#      ADME MDCK(WT) Permeability;Concat;Comments  \
# 0                                           NaN
# 1                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# ...                                         ...
# 6144                                        NaN
# 6145                                        NaN
# 6146                                        NaN
# 6147                                        NaN
# 6148                                        NaN
#
#      ADME MDCK(WT) Permeability;Concat;Run Date  ...  \
# 0                                           NaN  ...
# 1                                           NaN  ...
# 4                                           NaN  ...
# 5                                           NaN  ...
# 6                                           NaN  ...
# ...                                         ...  ...
# 6144                                        NaN  ...
# 6145                                        NaN  ...
# 6146                                        NaN  ...
# 6147                                        NaN  ...
# 6148                                        NaN  ...
#
#       ADME Tox-manual patch hERG 34C;Mean;SD;(Mod)  \
# 0                                                =
# 1                                                =
# 4                                                =
# 5                                                =
# 6                                                =
# ...                                            ...
# 6144                                           NaN
# 6145                                           NaN
# 6146                                           NaN
# 6147                                           NaN
# 6148                                           NaN
#
#       ADME Tox-manual patch hERG 34C;Mean;SD;(Num) F%_Rat  EstFa_Rat  \
# 0                                         0.467074  10.80   0.125258
# 1                                         1.265248   3.87   0.048645
# 4                                         2.719742   7.30   0.104952
# 5                                         4.550594  20.60   0.261864
# 6                                         4.607898   4.30   0.067422
# ...                                            ...    ...        ...
# 6144                                           NaN   1.09   0.011158
# 6145                                           NaN   3.00   0.030241
# 6146                                           NaN   2.40   0.024432
# 6147                                           NaN  27.40   0.305652
# 6148                                           NaN   1.08   0.011823
#
#      permeability  efflux hERG_IC50 hERG_eIC50  hERG_mixedIC50 ambitiousData
# 0             NaN     NaN       NaN  11.044944       11.044944           1.0
# 1             NaN     NaN       NaN   9.259910        9.259910           1.0
# 4             NaN     NaN       NaN  16.841270       16.841270           1.0
# 5             NaN     NaN       NaN   9.647555        9.647555           1.0
# 6             NaN     NaN   25.5965        NaN       25.596500           0.0
# ...           ...     ...       ...        ...             ...           ...
# 6144          NaN     NaN       NaN        NaN             NaN           NaN
# 6145          NaN     NaN       NaN        NaN             NaN           NaN
# 6146          NaN     NaN       NaN        NaN             NaN           NaN
# 6147          NaN     NaN       NaN        NaN             NaN           NaN
# 6148          NaN     NaN       NaN        NaN             NaN           NaN
#
# [2602 rows x 48 columns]
