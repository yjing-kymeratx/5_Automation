# %%
import copy
import sqlite3
import numpy as np
import pandas as pd
from rdkit import Chem

# %%
def call_my_query(db_file, my_query):
    ## connect to the SQLIte database
    my_connection = sqlite3.connect(db_file)

    ## create a cursor object
    my_cursor = my_connection.cursor()

    ## excute the query
    my_cursor.execute(my_query)

    ## fetch all the rows
    rows = my_cursor.fetchall()
    
    ## export the results
    data_list = [row for row in rows]

    my_connection.close()
    return data_list

def extract_tables(db_file, table_name):
    ## extract table data from SQLite DB
    my_query_colName = f"PRAGMA table_info({table_name})"
    colName_list = call_my_query(db_file, my_query_colName)

    my_query_data = f"SELECT * FROM {table_name}"
    data_list = call_my_query(db_file, my_query_data)

    ## clean up data
    dataDict = {}
    for row_tuple in data_list:
        idx = row_tuple[0]
        dataDict[idx] = {}

        for col in colName_list:
            colIdx, colName = col[0], col[1]
            dataDict[idx][colName] = row_tuple[colIdx]
    return dataDict

# %%
db_file = './results/Compounds_All.mmpdb'

dataDict_tables = {}
dataDict_dicts = {}

for table_name in ["pair", "compound", "compound_property", "property_name", "constant_smiles",
                   "rule", "rule_smiles", "rule_environment", "rule_environment_statistics", "environment_fingerprint"]:
    dataDict_table = extract_tables(db_file, table_name)
    dataDict_dicts[table_name] = dataDict_table
    dataDict_tables[table_name] = pd.DataFrame.from_dict(dataDict_table).T
    # print(table_name)

# %%
dataDict_pair = dataDict_dicts["pair"]
dataTable_pair = dataDict_tables["pair"].rename(columns={'id': 'pair_id'})

# %%
dataDict_pair
# Out:
# {1: {'id': 1,
#   'rule_environment_id': 1,
#   'compound1_id': 1,
#   'compound2_id': 2,
#   'constant_id': 1},
#  2: {'id': 2,
#   'rule_environment_id': 2,
#   'compound1_id': 1,
#   'compound2_id': 2,
#   'constant_id': 1},
#  3: {'id': 3,
#   'rule_environment_id': 3,
#   'compound1_id': 1,
#   'compound2_id': 2,
#   'constant_id': 1},
#  4: {'id': 4,
#   'rule_environment_id': 4,
#   'compound1_id': 1,
#   'compound2_id': 2,
#   'constant_id': 1},
#  5: {'id': 5,
#   'rule_environment_id': 5,
#   'compound1_id': 1,
#   'compound2_id': 2,
#   'constant_id': 1},
#  6: {'id': 6,
#   'rule_environment_id': 6,
#   'compound1_id': 1,
#   'compound2_id': 2,
#   'constant_id': 1},
#  7: {'id': 7,
#   'rule_environment_id': 7,
#   'compound1_id': 3,
#   'compound2_id': 4,
#   'constant_id': 2},
#  8: {'id': 8,
#   'rule_environment_id': 8,
#   'compound1_id': 3,
#   'compound2_id': 4,
#   'constant_id': 2},
#  9: {'id': 9,
#   'rule_environment_id': 9,
#   'compound1_id': 3,
#   'compound2_id': 4,
#   'constant_id': 2},
#  10: {'id': 10,
#   'rule_environment_id': 10,
#   'compound1_id': 3,
#   'compound2_id': 4,
#   'constant_id': 2},
#  11: {'id': 11,
#   'rule_environment_id': 11,
#   'compound1_id': 3,
#   'compound2_id': 4,
#   'constant_id': 2},
#  12: {'id': 12,
#   'rule_environment_id': 12,
#   'compound1_id': 3,
#   'compound2_id': 4,
#   'constant_id': 2},
#  13: {'id': 13,
#   'rule_environment_id': 13,
#   'compound1_id': 4,
#   'compound2_id': 5,
#   'constant_id': 2},
#  14: {'id': 14,
#   'rule_environment_id': 14,
#   'compound1_id': 4,
#   'compound2_id': 5,
#   'constant_id': 2},
#  15: {'id': 15,
#   'rule_environment_id': 15,
#   'compound1_id': 4,
#   'compound2_id': 5,
#   'constant_id': 2},
#  16: {'id': 16,
#   'rule_environment_id': 16,
#   'compound1_id': 4,
#   'compound2_id': 5,
#   'constant_id': 2},
#  17: {'id': 17,
#   'rule_environment_id': 17,
#   'compound1_id': 4,
#   'compound2_id': 5,
#   'constant_id': 2},
#  18: {'id': 18,
#   'rule_environment_id': 18,
#   'compound1_id': 4,
#   'compound2_id': 5,
#   'constant_id': 2},
#  19: {'id': 19,
#   'rule_environment_id': 19,
#   'compound1_id': 6,
#   'compound2_id': 4,
#   'constant_id': 2},
#  20: {'id': 20,
#   'rule_environment_id': 20,
#   'compound1_id': 6,
#   'compound2_id': 4,
#   'constant_id': 2},
#  21: {'id': 21,
#   'rule_environment_id': 21,
#   'compound1_id': 6,
#   'compound2_id': 4,
#   'constant_id': 2},
#  22: {'id': 22,
#   'rule_environment_id': 22,
#   'compound1_id': 6,
#   'compound2_id': 4,
#   'constant_id': 2},
#  23: {'id': 23,
#   'rule_environment_id': 23,
#   'compound1_id': 6,
#   'compound2_id': 4,
#   'constant_id': 2},
#  24: {'id': 24,
#   'rule_environment_id': 24,
#   'compound1_id': 6,
#   'compound2_id': 4,
#   'constant_id': 2},
#  25: {'id': 25,
#   'rule_environment_id': 25,
#   'compound1_id': 3,
#   'compound2_id': 5,
#   'constant_id': 2},
#  26: {'id': 26,
#   'rule_environment_id': 26,
#   'compound1_id': 3,
#   'compound2_id': 5,
#   'constant_id': 2},
#  27: {'id': 27,
#   'rule_environment_id': 27,
#   'compound1_id': 3,
#   'compound2_id': 5,
#   'constant_id': 2},
#  28: {'id': 28,
#   'rule_environment_id': 28,
#   'compound1_id': 3,
#   'compound2_id': 5,
#   'constant_id': 2},
#  29: {'id': 29,
#   'rule_environment_id': 29,
#   'compound1_id': 3,
#   'compound2_id': 5,
#   'constant_id': 2},
#  30: {'id': 30,
#   'rule_environment_id': 30,
#   'compound1_id': 3,
#   'compound2_id': 5,
#   'constant_id': 2},
#  31: {'id': 31,
#   'rule_environment_id': 31,
#   'compound1_id': 3,
#   'compound2_id': 6,
#   'constant_id': 2},
#  32: {'id': 32,
#   'rule_environment_id': 32,
#   'compound1_id': 3,
#   'compound2_id': 6,
#   'constant_id': 2},
#  33: {'id': 33,
#   'rule_environment_id': 33,
#   'compound1_id': 3,
#   'compound2_id': 6,
#   'constant_id': 2},
#  34: {'id': 34,
#   'rule_environment_id': 34,
#   'compound1_id': 3,
#   'compound2_id': 6,
#   'constant_id': 2},
#  35: {'id': 35,
#   'rule_environment_id': 35,
#   'compound1_id': 3,
#   'compound2_id': 6,
#   'constant_id': 2},
#  36: {'id': 36,
#   'rule_environment_id': 36,
#   'compound1_id': 3,
#   'compound2_id': 6,
#   'constant_id': 2},
#  37: {'id': 37,
#   'rule_environment_id': 37,
#   'compound1_id': 6,
#   'compound2_id': 5,
#   'constant_id': 2},
#  38: {'id': 38,
#   'rule_environment_id': 38,
#   'compound1_id': 6,
#   'compound2_id': 5,
#   'constant_id': 2},
#  39: {'id': 39,
#   'rule_environment_id': 39,
#   'compound1_id': 6,
#   'compound2_id': 5,
#   'constant_id': 2},
#  40: {'id': 40,
#   'rule_environment_id': 40,
#   'compound1_id': 6,
#   'compound2_id': 5,
#   'constant_id': 2},
#  41: {'id': 41,
#   'rule_environment_id': 41,
#   'compound1_id': 6,
#   'compound2_id': 5,
#   'constant_id': 2},
#  42: {'id': 42,
#   'rule_environment_id': 42,
#   'compound1_id': 6,
#   'compound2_id': 5,
#   'constant_id': 2},
#  43: {'id': 43,
#   'rule_environment_id': 43,
#   'compound1_id': 7,
#   'compound2_id': 3,
#   'constant_id': 3},
#  44: {'id': 44,
#   'rule_environment_id': 44,
#   'compound1_id': 7,
#   'compound2_id': 3,
#   'constant_id': 3},
#  45: {'id': 45,
#   'rule_environment_id': 45,
#   'compound1_id': 7,
#   'compound2_id': 3,
#   'constant_id': 3},
#  46: {'id': 46,
#   'rule_environment_id': 46,
#   'compound1_id': 7,
#   'compound2_id': 3,
#   'constant_id': 3},
#  47: {'id': 47,
#   'rule_environment_id': 47,
#   'compound1_id': 7,
#   'compound2_id': 3,
#   'constant_id': 3},
#  48: {'id': 48,
#   'rule_environment_id': 48,
#   'compound1_id': 7,
#   'compound2_id': 3,
#   'constant_id': 3},
#  49: {'id': 49,
#   'rule_environment_id': 49,
#   'compound1_id': 7,
#   'compound2_id': 8,
#   'constant_id': 3},
#  50: {'id': 50,
#   'rule_environment_id': 50,
#   'compound1_id': 7,
#   'compound2_id': 8,
#   'constant_id': 3},
#  51: {'id': 51,
#   'rule_environment_id': 51,
#   'compound1_id': 7,
#   'compound2_id': 8,
#   'constant_id': 3},
#  52: {'id': 52,
#   'rule_environment_id': 52,
#   'compound1_id': 7,
#   'compound2_id': 8,
#   'constant_id': 3},
#  53: {'id': 53,
#   'rule_environment_id': 53,
#   'compound1_id': 7,
#   'compound2_id': 8,
#   'constant_id': 3},
#  54: {'id': 54,
#   'rule_environment_id': 54,
#   'compound1_id': 7,
#   'compound2_id': 8,
#   'constant_id': 3},
#  55: {'id': 55,
#   'rule_environment_id': 55,
#   'compound1_id': 3,
#   'compound2_id': 8,
#   'constant_id': 3},
#  56: {'id': 56,
#   'rule_environment_id': 56,
#   'compound1_id': 3,
#   'compound2_id': 8,
#   'constant_id': 3},
#  57: {'id': 57,
#   'rule_environment_id': 57,
#   'compound1_id': 3,
#   'compound2_id': 8,
#   'constant_id': 3},
#  58: {'id': 58,
#   'rule_environment_id': 58,
#   'compound1_id': 3,
#   'compound2_id': 8,
#   'constant_id': 3},
#  59: {'id': 59,
#   'rule_environment_id': 59,
#   'compound1_id': 3,
#   'compound2_id': 8,
#   'constant_id': 3},
#  60: {'id': 60,
#   'rule_environment_id': 60,
#   'compound1_id': 3,
#   'compound2_id': 8,
#   'constant_id': 3},
#  61: {'id': 61,
#   'rule_environment_id': 61,
#   'compound1_id': 9,
#   'compound2_id': 10,
#   'constant_id': 4},
#  62: {'id': 62,
#   'rule_environment_id': 62,
#   'compound1_id': 9,
#   'compound2_id': 10,
#   'constant_id': 4},
#  63: {'id': 63,
#   'rule_environment_id': 63,
#   'compound1_id': 9,
#   'compound2_id': 10,
#   'constant_id': 4},
#  64: {'id': 64,
#   'rule_environment_id': 64,
#   'compound1_id': 9,
#   'compound2_id': 10,
#   'constant_id': 4},
#  65: {'id': 65,
#   'rule_environment_id': 65,
#   'compound1_id': 9,
#   'compound2_id': 10,
#   'constant_id': 4},
#  66: {'id': 66,
#   'rule_environment_id': 66,
#   'compound1_id': 9,
#   'compound2_id': 10,
#   'constant_id': 4},
#  67: {'id': 67,
#   'rule_environment_id': 67,
#   'compound1_id': 11,
#   'compound2_id': 12,
#   'constant_id': 5},
#  68: {'id': 68,
#   'rule_environment_id': 68,
#   'compound1_id': 11,
#   'compound2_id': 12,
#   'constant_id': 5},
#  69: {'id': 69,
#   'rule_environment_id': 69,
#   'compound1_id': 11,
#   'compound2_id': 12,
#   'constant_id': 5},
#  70: {'id': 70,
#   'rule_environment_id': 70,
#   'compound1_id': 11,
#   'compound2_id': 12,
#   'constant_id': 5},
#  71: {'id': 71,
#   'rule_environment_id': 71,
#   'compound1_id': 11,
#   'compound2_id': 12,
#   'constant_id': 5},
#  72: {'id': 72,
#   'rule_environment_id': 72,
#   'compound1_id': 11,
#   'compound2_id': 12,
#   'constant_id': 5},
#  73: {'id': 73,
#   'rule_environment_id': 73,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 6},
#  74: {'id': 74,
#   'rule_environment_id': 74,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 6},
#  75: {'id': 75,
#   'rule_environment_id': 75,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 6},
#  76: {'id': 76,
#   'rule_environment_id': 76,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 6},
#  77: {'id': 77,
#   'rule_environment_id': 77,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 6},
#  78: {'id': 78,
#   'rule_environment_id': 78,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 6},
#  79: {'id': 79,
#   'rule_environment_id': 79,
#   'compound1_id': 13,
#   'compound2_id': 12,
#   'constant_id': 6},
#  80: {'id': 80,
#   'rule_environment_id': 80,
#   'compound1_id': 13,
#   'compound2_id': 12,
#   'constant_id': 6},
#  81: {'id': 81,
#   'rule_environment_id': 81,
#   'compound1_id': 13,
#   'compound2_id': 12,
#   'constant_id': 6},
#  82: {'id': 82,
#   'rule_environment_id': 82,
#   'compound1_id': 13,
#   'compound2_id': 12,
#   'constant_id': 6},
#  83: {'id': 83,
#   'rule_environment_id': 83,
#   'compound1_id': 13,
#   'compound2_id': 12,
#   'constant_id': 6},
#  84: {'id': 84,
#   'rule_environment_id': 84,
#   'compound1_id': 13,
#   'compound2_id': 12,
#   'constant_id': 6},
#  85: {'id': 85,
#   'rule_environment_id': 85,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 7},
#  86: {'id': 86,
#   'rule_environment_id': 86,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 7},
#  87: {'id': 87,
#   'rule_environment_id': 87,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 7},
#  88: {'id': 88,
#   'rule_environment_id': 88,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 7},
#  89: {'id': 89,
#   'rule_environment_id': 89,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 7},
#  90: {'id': 90,
#   'rule_environment_id': 90,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 7},
#  91: {'id': 91,
#   'rule_environment_id': 91,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 7},
#  92: {'id': 92,
#   'rule_environment_id': 92,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 7},
#  93: {'id': 93,
#   'rule_environment_id': 93,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 7},
#  94: {'id': 94,
#   'rule_environment_id': 94,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 7},
#  95: {'id': 95,
#   'rule_environment_id': 95,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 7},
#  96: {'id': 96,
#   'rule_environment_id': 96,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 7},
#  97: {'id': 97,
#   'rule_environment_id': 97,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 7},
#  98: {'id': 98,
#   'rule_environment_id': 98,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 7},
#  99: {'id': 99,
#   'rule_environment_id': 99,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 7},
#  100: {'id': 100,
#   'rule_environment_id': 100,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 7},
#  101: {'id': 101,
#   'rule_environment_id': 101,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 7},
#  102: {'id': 102,
#   'rule_environment_id': 102,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 7},
#  103: {'id': 103,
#   'rule_environment_id': 103,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 7},
#  104: {'id': 104,
#   'rule_environment_id': 104,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 7},
#  105: {'id': 105,
#   'rule_environment_id': 105,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 7},
#  106: {'id': 106,
#   'rule_environment_id': 106,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 7},
#  107: {'id': 107,
#   'rule_environment_id': 107,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 7},
#  108: {'id': 108,
#   'rule_environment_id': 108,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 7},
#  109: {'id': 109,
#   'rule_environment_id': 109,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 7},
#  110: {'id': 110,
#   'rule_environment_id': 110,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 7},
#  111: {'id': 111,
#   'rule_environment_id': 111,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 7},
#  112: {'id': 112,
#   'rule_environment_id': 112,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 7},
#  113: {'id': 113,
#   'rule_environment_id': 113,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 7},
#  114: {'id': 114,
#   'rule_environment_id': 114,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 7},
#  115: {'id': 115,
#   'rule_environment_id': 115,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 7},
#  116: {'id': 116,
#   'rule_environment_id': 116,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 7},
#  117: {'id': 117,
#   'rule_environment_id': 117,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 7},
#  118: {'id': 118,
#   'rule_environment_id': 118,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 7},
#  119: {'id': 119,
#   'rule_environment_id': 119,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 7},
#  120: {'id': 120,
#   'rule_environment_id': 120,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 7},
#  121: {'id': 121,
#   'rule_environment_id': 121,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 8},
#  122: {'id': 122,
#   'rule_environment_id': 122,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 8},
#  123: {'id': 123,
#   'rule_environment_id': 123,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 8},
#  124: {'id': 124,
#   'rule_environment_id': 124,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 8},
#  125: {'id': 125,
#   'rule_environment_id': 125,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 8},
#  126: {'id': 126,
#   'rule_environment_id': 126,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 8},
#  127: {'id': 127,
#   'rule_environment_id': 121,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 8},
#  128: {'id': 128,
#   'rule_environment_id': 122,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 8},
#  129: {'id': 129,
#   'rule_environment_id': 123,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 8},
#  130: {'id': 130,
#   'rule_environment_id': 124,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 8},
#  131: {'id': 131,
#   'rule_environment_id': 125,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 8},
#  132: {'id': 132,
#   'rule_environment_id': 126,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 8},
#  133: {'id': 133,
#   'rule_environment_id': 121,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 8},
#  134: {'id': 134,
#   'rule_environment_id': 122,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 8},
#  135: {'id': 135,
#   'rule_environment_id': 123,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 8},
#  136: {'id': 136,
#   'rule_environment_id': 124,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 8},
#  137: {'id': 137,
#   'rule_environment_id': 125,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 8},
#  138: {'id': 138,
#   'rule_environment_id': 126,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 8},
#  139: {'id': 139,
#   'rule_environment_id': 121,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 8},
#  140: {'id': 140,
#   'rule_environment_id': 122,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 8},
#  141: {'id': 141,
#   'rule_environment_id': 123,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 8},
#  142: {'id': 142,
#   'rule_environment_id': 124,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 8},
#  143: {'id': 143,
#   'rule_environment_id': 125,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 8},
#  144: {'id': 144,
#   'rule_environment_id': 126,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 8},
#  145: {'id': 145,
#   'rule_environment_id': 85,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 9},
#  146: {'id': 146,
#   'rule_environment_id': 86,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 9},
#  147: {'id': 147,
#   'rule_environment_id': 87,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 9},
#  148: {'id': 148,
#   'rule_environment_id': 88,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 9},
#  149: {'id': 149,
#   'rule_environment_id': 89,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 9},
#  150: {'id': 150,
#   'rule_environment_id': 90,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 9},
#  151: {'id': 151,
#   'rule_environment_id': 127,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 10},
#  152: {'id': 152,
#   'rule_environment_id': 128,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 10},
#  153: {'id': 153,
#   'rule_environment_id': 129,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 10},
#  154: {'id': 154,
#   'rule_environment_id': 130,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 10},
#  155: {'id': 155,
#   'rule_environment_id': 131,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 10},
#  156: {'id': 156,
#   'rule_environment_id': 132,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 10},
#  157: {'id': 157,
#   'rule_environment_id': 133,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 11},
#  158: {'id': 158,
#   'rule_environment_id': 134,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 11},
#  159: {'id': 159,
#   'rule_environment_id': 135,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 11},
#  160: {'id': 160,
#   'rule_environment_id': 136,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 11},
#  161: {'id': 161,
#   'rule_environment_id': 137,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 11},
#  162: {'id': 162,
#   'rule_environment_id': 138,
#   'compound1_id': 20,
#   'compound2_id': 21,
#   'constant_id': 11},
#  163: {'id': 163,
#   'rule_environment_id': 139,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 12},
#  164: {'id': 164,
#   'rule_environment_id': 140,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 12},
#  165: {'id': 165,
#   'rule_environment_id': 141,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 12},
#  166: {'id': 166,
#   'rule_environment_id': 142,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 12},
#  167: {'id': 167,
#   'rule_environment_id': 143,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 12},
#  168: {'id': 168,
#   'rule_environment_id': 144,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 12},
#  169: {'id': 169,
#   'rule_environment_id': 145,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 13},
#  170: {'id': 170,
#   'rule_environment_id': 146,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 13},
#  171: {'id': 171,
#   'rule_environment_id': 147,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 13},
#  172: {'id': 172,
#   'rule_environment_id': 148,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 13},
#  173: {'id': 173,
#   'rule_environment_id': 149,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 13},
#  174: {'id': 174,
#   'rule_environment_id': 150,
#   'compound1_id': 22,
#   'compound2_id': 23,
#   'constant_id': 13},
#  175: {'id': 175,
#   'rule_environment_id': 151,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 14},
#  176: {'id': 176,
#   'rule_environment_id': 152,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 14},
#  177: {'id': 177,
#   'rule_environment_id': 153,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 14},
#  178: {'id': 178,
#   'rule_environment_id': 154,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 14},
#  179: {'id': 179,
#   'rule_environment_id': 155,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 14},
#  180: {'id': 180,
#   'rule_environment_id': 156,
#   'compound1_id': 13,
#   'compound2_id': 11,
#   'constant_id': 14},
#  181: {'id': 181,
#   'rule_environment_id': 157,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  182: {'id': 182,
#   'rule_environment_id': 158,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  183: {'id': 183,
#   'rule_environment_id': 159,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  184: {'id': 184,
#   'rule_environment_id': 160,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  185: {'id': 185,
#   'rule_environment_id': 161,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  186: {'id': 186,
#   'rule_environment_id': 162,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  187: {'id': 187,
#   'rule_environment_id': 163,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  188: {'id': 188,
#   'rule_environment_id': 164,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  189: {'id': 189,
#   'rule_environment_id': 165,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  190: {'id': 190,
#   'rule_environment_id': 166,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  191: {'id': 191,
#   'rule_environment_id': 167,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  192: {'id': 192,
#   'rule_environment_id': 168,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  193: {'id': 193,
#   'rule_environment_id': 169,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  194: {'id': 194,
#   'rule_environment_id': 170,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  195: {'id': 195,
#   'rule_environment_id': 171,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  196: {'id': 196,
#   'rule_environment_id': 172,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  197: {'id': 197,
#   'rule_environment_id': 173,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  198: {'id': 198,
#   'rule_environment_id': 174,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  199: {'id': 199,
#   'rule_environment_id': 175,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  200: {'id': 200,
#   'rule_environment_id': 176,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  201: {'id': 201,
#   'rule_environment_id': 177,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  202: {'id': 202,
#   'rule_environment_id': 178,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  203: {'id': 203,
#   'rule_environment_id': 179,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  204: {'id': 204,
#   'rule_environment_id': 180,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  205: {'id': 205,
#   'rule_environment_id': 181,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  206: {'id': 206,
#   'rule_environment_id': 182,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  207: {'id': 207,
#   'rule_environment_id': 183,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  208: {'id': 208,
#   'rule_environment_id': 184,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  209: {'id': 209,
#   'rule_environment_id': 185,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  210: {'id': 210,
#   'rule_environment_id': 186,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  211: {'id': 211,
#   'rule_environment_id': 187,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  212: {'id': 212,
#   'rule_environment_id': 188,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  213: {'id': 213,
#   'rule_environment_id': 189,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  214: {'id': 214,
#   'rule_environment_id': 190,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  215: {'id': 215,
#   'rule_environment_id': 191,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  216: {'id': 216,
#   'rule_environment_id': 192,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  217: {'id': 217,
#   'rule_environment_id': 193,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  218: {'id': 218,
#   'rule_environment_id': 194,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  219: {'id': 219,
#   'rule_environment_id': 195,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  220: {'id': 220,
#   'rule_environment_id': 196,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  221: {'id': 221,
#   'rule_environment_id': 197,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  222: {'id': 222,
#   'rule_environment_id': 198,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  223: {'id': 223,
#   'rule_environment_id': 199,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  224: {'id': 224,
#   'rule_environment_id': 200,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  225: {'id': 225,
#   'rule_environment_id': 201,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  226: {'id': 226,
#   'rule_environment_id': 202,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  227: {'id': 227,
#   'rule_environment_id': 203,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  228: {'id': 228,
#   'rule_environment_id': 204,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  229: {'id': 229,
#   'rule_environment_id': 205,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  230: {'id': 230,
#   'rule_environment_id': 206,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  231: {'id': 231,
#   'rule_environment_id': 207,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  232: {'id': 232,
#   'rule_environment_id': 208,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  233: {'id': 233,
#   'rule_environment_id': 209,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  234: {'id': 234,
#   'rule_environment_id': 210,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  235: {'id': 235,
#   'rule_environment_id': 211,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  236: {'id': 236,
#   'rule_environment_id': 212,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  237: {'id': 237,
#   'rule_environment_id': 213,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  238: {'id': 238,
#   'rule_environment_id': 214,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  239: {'id': 239,
#   'rule_environment_id': 215,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  240: {'id': 240,
#   'rule_environment_id': 216,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  241: {'id': 241,
#   'rule_environment_id': 217,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  242: {'id': 242,
#   'rule_environment_id': 218,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  243: {'id': 243,
#   'rule_environment_id': 219,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  244: {'id': 244,
#   'rule_environment_id': 220,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  245: {'id': 245,
#   'rule_environment_id': 221,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  246: {'id': 246,
#   'rule_environment_id': 222,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  247: {'id': 247,
#   'rule_environment_id': 223,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  248: {'id': 248,
#   'rule_environment_id': 224,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  249: {'id': 249,
#   'rule_environment_id': 225,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  250: {'id': 250,
#   'rule_environment_id': 226,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  251: {'id': 251,
#   'rule_environment_id': 227,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  252: {'id': 252,
#   'rule_environment_id': 228,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  253: {'id': 253,
#   'rule_environment_id': 229,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  254: {'id': 254,
#   'rule_environment_id': 230,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  255: {'id': 255,
#   'rule_environment_id': 231,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  256: {'id': 256,
#   'rule_environment_id': 232,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  257: {'id': 257,
#   'rule_environment_id': 233,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  258: {'id': 258,
#   'rule_environment_id': 234,
#   'compound1_id': 14,
#   'compound2_id': 15,
#   'constant_id': 15},
#  259: {'id': 259,
#   'rule_environment_id': 235,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  260: {'id': 260,
#   'rule_environment_id': 236,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  261: {'id': 261,
#   'rule_environment_id': 237,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  262: {'id': 262,
#   'rule_environment_id': 238,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  263: {'id': 263,
#   'rule_environment_id': 239,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  264: {'id': 264,
#   'rule_environment_id': 240,
#   'compound1_id': 15,
#   'compound2_id': 16,
#   'constant_id': 15},
#  265: {'id': 265,
#   'rule_environment_id': 241,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  266: {'id': 266,
#   'rule_environment_id': 242,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  267: {'id': 267,
#   'rule_environment_id': 243,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  268: {'id': 268,
#   'rule_environment_id': 244,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  269: {'id': 269,
#   'rule_environment_id': 245,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  270: {'id': 270,
#   'rule_environment_id': 246,
#   'compound1_id': 15,
#   'compound2_id': 17,
#   'constant_id': 15},
#  271: {'id': 271,
#   'rule_environment_id': 247,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  272: {'id': 272,
#   'rule_environment_id': 248,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  273: {'id': 273,
#   'rule_environment_id': 249,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  274: {'id': 274,
#   'rule_environment_id': 250,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  275: {'id': 275,
#   'rule_environment_id': 251,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  276: {'id': 276,
#   'rule_environment_id': 252,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  277: {'id': 277,
#   'rule_environment_id': 253,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  278: {'id': 278,
#   'rule_environment_id': 254,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  279: {'id': 279,
#   'rule_environment_id': 255,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  280: {'id': 280,
#   'rule_environment_id': 256,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  281: {'id': 281,
#   'rule_environment_id': 257,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  282: {'id': 282,
#   'rule_environment_id': 258,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  283: {'id': 283,
#   'rule_environment_id': 259,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  284: {'id': 284,
#   'rule_environment_id': 260,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  285: {'id': 285,
#   'rule_environment_id': 261,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  286: {'id': 286,
#   'rule_environment_id': 262,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  287: {'id': 287,
#   'rule_environment_id': 263,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  288: {'id': 288,
#   'rule_environment_id': 264,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  289: {'id': 289,
#   'rule_environment_id': 265,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  290: {'id': 290,
#   'rule_environment_id': 266,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  291: {'id': 291,
#   'rule_environment_id': 267,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  292: {'id': 292,
#   'rule_environment_id': 268,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  293: {'id': 293,
#   'rule_environment_id': 269,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  294: {'id': 294,
#   'rule_environment_id': 270,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  295: {'id': 295,
#   'rule_environment_id': 271,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  296: {'id': 296,
#   'rule_environment_id': 272,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  297: {'id': 297,
#   'rule_environment_id': 273,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  298: {'id': 298,
#   'rule_environment_id': 274,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  299: {'id': 299,
#   'rule_environment_id': 275,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  300: {'id': 300,
#   'rule_environment_id': 276,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  301: {'id': 301,
#   'rule_environment_id': 277,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  302: {'id': 302,
#   'rule_environment_id': 278,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  303: {'id': 303,
#   'rule_environment_id': 279,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  304: {'id': 304,
#   'rule_environment_id': 280,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  305: {'id': 305,
#   'rule_environment_id': 281,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  306: {'id': 306,
#   'rule_environment_id': 282,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  307: {'id': 307,
#   'rule_environment_id': 283,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  308: {'id': 308,
#   'rule_environment_id': 284,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  309: {'id': 309,
#   'rule_environment_id': 285,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  310: {'id': 310,
#   'rule_environment_id': 286,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  311: {'id': 311,
#   'rule_environment_id': 287,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  312: {'id': 312,
#   'rule_environment_id': 288,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  313: {'id': 313,
#   'rule_environment_id': 289,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  314: {'id': 314,
#   'rule_environment_id': 290,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  315: {'id': 315,
#   'rule_environment_id': 291,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  316: {'id': 316,
#   'rule_environment_id': 292,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  317: {'id': 317,
#   'rule_environment_id': 293,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  318: {'id': 318,
#   'rule_environment_id': 294,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  319: {'id': 319,
#   'rule_environment_id': 295,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  320: {'id': 320,
#   'rule_environment_id': 296,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  321: {'id': 321,
#   'rule_environment_id': 297,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  322: {'id': 322,
#   'rule_environment_id': 298,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  323: {'id': 323,
#   'rule_environment_id': 299,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  324: {'id': 324,
#   'rule_environment_id': 300,
#   'compound1_id': 14,
#   'compound2_id': 16,
#   'constant_id': 15},
#  325: {'id': 325,
#   'rule_environment_id': 301,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  326: {'id': 326,
#   'rule_environment_id': 302,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  327: {'id': 327,
#   'rule_environment_id': 303,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  328: {'id': 328,
#   'rule_environment_id': 304,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  329: {'id': 329,
#   'rule_environment_id': 305,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  330: {'id': 330,
#   'rule_environment_id': 306,
#   'compound1_id': 14,
#   'compound2_id': 17,
#   'constant_id': 15},
#  331: {'id': 331,
#   'rule_environment_id': 307,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  332: {'id': 332,
#   'rule_environment_id': 308,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  333: {'id': 333,
#   'rule_environment_id': 309,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  334: {'id': 334,
#   'rule_environment_id': 310,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  335: {'id': 335,
#   'rule_environment_id': 311,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  336: {'id': 336,
#   'rule_environment_id': 312,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  337: {'id': 337,
#   'rule_environment_id': 313,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  338: {'id': 338,
#   'rule_environment_id': 314,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  339: {'id': 339,
#   'rule_environment_id': 315,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  340: {'id': 340,
#   'rule_environment_id': 316,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  341: {'id': 341,
#   'rule_environment_id': 317,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  342: {'id': 342,
#   'rule_environment_id': 318,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  343: {'id': 343,
#   'rule_environment_id': 319,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  344: {'id': 344,
#   'rule_environment_id': 320,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  345: {'id': 345,
#   'rule_environment_id': 321,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  346: {'id': 346,
#   'rule_environment_id': 322,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  347: {'id': 347,
#   'rule_environment_id': 323,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  348: {'id': 348,
#   'rule_environment_id': 324,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  349: {'id': 349,
#   'rule_environment_id': 325,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  350: {'id': 350,
#   'rule_environment_id': 326,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  351: {'id': 351,
#   'rule_environment_id': 327,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  352: {'id': 352,
#   'rule_environment_id': 328,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  353: {'id': 353,
#   'rule_environment_id': 329,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  354: {'id': 354,
#   'rule_environment_id': 330,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  355: {'id': 355,
#   'rule_environment_id': 331,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  356: {'id': 356,
#   'rule_environment_id': 332,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  357: {'id': 357,
#   'rule_environment_id': 333,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  358: {'id': 358,
#   'rule_environment_id': 334,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  359: {'id': 359,
#   'rule_environment_id': 335,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  360: {'id': 360,
#   'rule_environment_id': 336,
#   'compound1_id': 16,
#   'compound2_id': 17,
#   'constant_id': 15},
#  361: {'id': 361,
#   'rule_environment_id': 157,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  362: {'id': 362,
#   'rule_environment_id': 158,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  363: {'id': 363,
#   'rule_environment_id': 159,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  364: {'id': 364,
#   'rule_environment_id': 160,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  365: {'id': 365,
#   'rule_environment_id': 161,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  366: {'id': 366,
#   'rule_environment_id': 162,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  367: {'id': 367,
#   'rule_environment_id': 163,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  368: {'id': 368,
#   'rule_environment_id': 164,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  369: {'id': 369,
#   'rule_environment_id': 165,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  370: {'id': 370,
#   'rule_environment_id': 166,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  371: {'id': 371,
#   'rule_environment_id': 167,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  372: {'id': 372,
#   'rule_environment_id': 168,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  373: {'id': 373,
#   'rule_environment_id': 169,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  374: {'id': 374,
#   'rule_environment_id': 170,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  375: {'id': 375,
#   'rule_environment_id': 171,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  376: {'id': 376,
#   'rule_environment_id': 172,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  377: {'id': 377,
#   'rule_environment_id': 173,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  378: {'id': 378,
#   'rule_environment_id': 174,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  379: {'id': 379,
#   'rule_environment_id': 211,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  380: {'id': 380,
#   'rule_environment_id': 212,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  381: {'id': 381,
#   'rule_environment_id': 213,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  382: {'id': 382,
#   'rule_environment_id': 214,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  383: {'id': 383,
#   'rule_environment_id': 215,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  384: {'id': 384,
#   'rule_environment_id': 216,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  385: {'id': 385,
#   'rule_environment_id': 229,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  386: {'id': 386,
#   'rule_environment_id': 230,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  387: {'id': 387,
#   'rule_environment_id': 231,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  388: {'id': 388,
#   'rule_environment_id': 232,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  389: {'id': 389,
#   'rule_environment_id': 233,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  390: {'id': 390,
#   'rule_environment_id': 234,
#   'compound1_id': 18,
#   'compound2_id': 19,
#   'constant_id': 16},
#  391: {'id': 391,
#   'rule_environment_id': 337,
#   'compound1_id': 24,
#   'compound2_id': 25,
#   'constant_id': 17},
#  392: {'id': 392,
#   'rule_environment_id': 338,
#   'compound1_id': 24,
#   'compound2_id': 25,
#   'constant_id': 17},
#  393: {'id': 393,
#   'rule_environment_id': 339,
#   'compound1_id': 24,
#   'compound2_id': 25,
#   'constant_id': 17},
#  394: {'id': 394,
#   'rule_environment_id': 340,
#   'compound1_id': 24,
#   'compound2_id': 25,
#   'constant_id': 17},
#  395: {'id': 395,
#   'rule_environment_id': 341,
#   'compound1_id': 24,
#   'compound2_id': 25,
#   'constant_id': 17},
#  396: {'id': 396,
#   'rule_environment_id': 342,
#   'compound1_id': 24,
#   'compound2_id': 25,
#   'constant_id': 17},
#  397: {'id': 397,
#   'rule_environment_id': 343,
#   'compound1_id': 26,
#   'compound2_id': 25,
#   'constant_id': 17},
#  398: {'id': 398,
#   'rule_environment_id': 344,
#   'compound1_id': 26,
#   'compound2_id': 25,
#   'constant_id': 17},
#  399: {'id': 399,
#   'rule_environment_id': 345,
#   'compound1_id': 26,
#   'compound2_id': 25,
#   'constant_id': 17},
#  400: {'id': 400,
#   'rule_environment_id': 346,
#   'compound1_id': 26,
#   'compound2_id': 25,
#   'constant_id': 17},
#  401: {'id': 401,
#   'rule_environment_id': 347,
#   'compound1_id': 26,
#   'compound2_id': 25,
#   'constant_id': 17},
#  402: {'id': 402,
#   'rule_environment_id': 348,
#   'compound1_id': 26,
#   'compound2_id': 25,
#   'constant_id': 17},
#  403: {'id': 403,
#   'rule_environment_id': 349,
#   'compound1_id': 24,
#   'compound2_id': 26,
#   'constant_id': 17},
#  404: {'id': 404,
#   'rule_environment_id': 350,
#   'compound1_id': 24,
#   'compound2_id': 26,
#   'constant_id': 17},
#  405: {'id': 405,
#   'rule_environment_id': 351,
#   'compound1_id': 24,
#   'compound2_id': 26,
#   'constant_id': 17},
#  406: {'id': 406,
#   'rule_environment_id': 352,
#   'compound1_id': 24,
#   'compound2_id': 26,
#   'constant_id': 17},
#  407: {'id': 407,
#   'rule_environment_id': 353,
#   'compound1_id': 24,
#   'compound2_id': 26,
#   'constant_id': 17},
#  408: {'id': 408,
#   'rule_environment_id': 354,
#   'compound1_id': 24,
#   'compound2_id': 26,
#   'constant_id': 17},
#  409: {'id': 409,
#   'rule_environment_id': 355,
#   'compound1_id': 27,
#   'compound2_id': 28,
#   'constant_id': 18},
#  410: {'id': 410,
#   'rule_environment_id': 356,
#   'compound1_id': 27,
#   'compound2_id': 28,
#   'constant_id': 18},
#  411: {'id': 411,
#   'rule_environment_id': 357,
#   'compound1_id': 27,
#   'compound2_id': 28,
#   'constant_id': 18},
#  412: {'id': 412,
#   'rule_environment_id': 358,
#   'compound1_id': 27,
#   'compound2_id': 28,
#   'constant_id': 18},
#  413: {'id': 413,
#   'rule_environment_id': 359,
#   'compound1_id': 27,
#   'compound2_id': 28,
#   'constant_id': 18},
#  414: {'id': 414,
#   'rule_environment_id': 360,
#   'compound1_id': 27,
#   'compound2_id': 28,
#   'constant_id': 18},
#  415: {'id': 415,
#   'rule_environment_id': 361,
#   'compound1_id': 29,
#   'compound2_id': 28,
#   'constant_id': 19},
#  416: {'id': 416,
#   'rule_environment_id': 362,
#   'compound1_id': 29,
#   'compound2_id': 28,
#   'constant_id': 19},
#  417: {'id': 417,
#   'rule_environment_id': 363,
#   'compound1_id': 29,
#   'compound2_id': 28,
#   'constant_id': 19},
#  418: {'id': 418,
#   'rule_environment_id': 364,
#   'compound1_id': 29,
#   'compound2_id': 28,
#   'constant_id': 19},
#  419: {'id': 419,
#   'rule_environment_id': 365,
#   'compound1_id': 29,
#   'compound2_id': 28,
#   'constant_id': 19},
#  420: {'id': 420,
#   'rule_environment_id': 366,
#   'compound1_id': 29,
#   'compound2_id': 28,
#   'constant_id': 19},
#  421: {'id': 421,
#   'rule_environment_id': 367,
#   'compound1_id': 30,
#   'compound2_id': 28,
#   'constant_id': 20},
#  422: {'id': 422,
#   'rule_environment_id': 368,
#   'compound1_id': 30,
#   'compound2_id': 28,
#   'constant_id': 20},
#  423: {'id': 423,
#   'rule_environment_id': 369,
#   'compound1_id': 30,
#   'compound2_id': 28,
#   'constant_id': 20},
#  424: {'id': 424,
#   'rule_environment_id': 370,
#   'compound1_id': 30,
#   'compound2_id': 28,
#   'constant_id': 20},
#  425: {'id': 425,
#   'rule_environment_id': 371,
#   'compound1_id': 30,
#   'compound2_id': 28,
#   'constant_id': 20},
#  426: {'id': 426,
#   'rule_environment_id': 372,
#   'compound1_id': 30,
#   'compound2_id': 28,
#   'constant_id': 20},
#  427: {'id': 427,
# ...
#   'constant_id': 31},
#  861: {'id': 861,
#   'rule_environment_id': 805,
#   'compound1_id': 5,
#   'compound2_id': 6,
#   'constant_id': 31},
#  862: {'id': 862,
#   'rule_environment_id': 806,
#   'compound1_id': 5,
#   'compound2_id': 6,
#   'constant_id': 31},
#  863: {'id': 863,
#   'rule_environment_id': 807,
#   'compound1_id': 5,
#   'compound2_id': 6,
#   'constant_id': 31},
#  864: {'id': 864,
#   'rule_environment_id': 808,
#   'compound1_id': 5,
#   'compound2_id': 6,
#   'constant_id': 31},
#  865: {'id': 865,
#   'rule_environment_id': 521,
#   'compound1_id': 46,
#   'compound2_id': 47,
#   'constant_id': 32},
#  866: {'id': 866,
#   'rule_environment_id': 809,
#   'compound1_id': 46,
#   'compound2_id': 47,
#   'constant_id': 32},
#  867: {'id': 867,
#   'rule_environment_id': 810,
#   'compound1_id': 46,
#   'compound2_id': 47,
#   'constant_id': 32},
#  868: {'id': 868,
#   'rule_environment_id': 811,
#   'compound1_id': 46,
#   'compound2_id': 47,
#   'constant_id': 32},
#  869: {'id': 869,
#   'rule_environment_id': 812,
#   'compound1_id': 46,
#   'compound2_id': 47,
#   'constant_id': 32},
#  870: {'id': 870,
#   'rule_environment_id': 813,
#   'compound1_id': 46,
#   'compound2_id': 47,
#   'constant_id': 32},
#  871: {'id': 871,
#   'rule_environment_id': 814,
#   'compound1_id': 46,
#   'compound2_id': 48,
#   'constant_id': 32},
#  872: {'id': 872,
#   'rule_environment_id': 815,
#   'compound1_id': 46,
#   'compound2_id': 48,
#   'constant_id': 32},
#  873: {'id': 873,
#   'rule_environment_id': 816,
#   'compound1_id': 46,
#   'compound2_id': 48,
#   'constant_id': 32},
#  874: {'id': 874,
#   'rule_environment_id': 817,
#   'compound1_id': 46,
#   'compound2_id': 48,
#   'constant_id': 32},
#  875: {'id': 875,
#   'rule_environment_id': 818,
#   'compound1_id': 46,
#   'compound2_id': 48,
#   'constant_id': 32},
#  876: {'id': 876,
#   'rule_environment_id': 819,
#   'compound1_id': 46,
#   'compound2_id': 48,
#   'constant_id': 32},
#  877: {'id': 877,
#   'rule_environment_id': 820,
#   'compound1_id': 46,
#   'compound2_id': 49,
#   'constant_id': 32},
#  878: {'id': 878,
#   'rule_environment_id': 821,
#   'compound1_id': 46,
#   'compound2_id': 49,
#   'constant_id': 32},
#  879: {'id': 879,
#   'rule_environment_id': 822,
#   'compound1_id': 46,
#   'compound2_id': 49,
#   'constant_id': 32},
#  880: {'id': 880,
#   'rule_environment_id': 823,
#   'compound1_id': 46,
#   'compound2_id': 49,
#   'constant_id': 32},
#  881: {'id': 881,
#   'rule_environment_id': 824,
#   'compound1_id': 46,
#   'compound2_id': 49,
#   'constant_id': 32},
#  882: {'id': 882,
#   'rule_environment_id': 825,
#   'compound1_id': 46,
#   'compound2_id': 49,
#   'constant_id': 32},
#  883: {'id': 883,
#   'rule_environment_id': 826,
#   'compound1_id': 47,
#   'compound2_id': 48,
#   'constant_id': 32},
#  884: {'id': 884,
#   'rule_environment_id': 827,
#   'compound1_id': 47,
#   'compound2_id': 48,
#   'constant_id': 32},
#  885: {'id': 885,
#   'rule_environment_id': 828,
#   'compound1_id': 47,
#   'compound2_id': 48,
#   'constant_id': 32},
#  886: {'id': 886,
#   'rule_environment_id': 829,
#   'compound1_id': 47,
#   'compound2_id': 48,
#   'constant_id': 32},
#  887: {'id': 887,
#   'rule_environment_id': 830,
#   'compound1_id': 47,
#   'compound2_id': 48,
#   'constant_id': 32},
#  888: {'id': 888,
#   'rule_environment_id': 831,
#   'compound1_id': 47,
#   'compound2_id': 48,
#   'constant_id': 32},
#  889: {'id': 889,
#   'rule_environment_id': 832,
#   'compound1_id': 47,
#   'compound2_id': 49,
#   'constant_id': 32},
#  890: {'id': 890,
#   'rule_environment_id': 833,
#   'compound1_id': 47,
#   'compound2_id': 49,
#   'constant_id': 32},
#  891: {'id': 891,
#   'rule_environment_id': 834,
#   'compound1_id': 47,
#   'compound2_id': 49,
#   'constant_id': 32},
#  892: {'id': 892,
#   'rule_environment_id': 835,
#   'compound1_id': 47,
#   'compound2_id': 49,
#   'constant_id': 32},
#  893: {'id': 893,
#   'rule_environment_id': 836,
#   'compound1_id': 47,
#   'compound2_id': 49,
#   'constant_id': 32},
#  894: {'id': 894,
#   'rule_environment_id': 837,
#   'compound1_id': 47,
#   'compound2_id': 49,
#   'constant_id': 32},
#  895: {'id': 895,
#   'rule_environment_id': 838,
#   'compound1_id': 49,
#   'compound2_id': 48,
#   'constant_id': 32},
#  896: {'id': 896,
#   'rule_environment_id': 839,
#   'compound1_id': 49,
#   'compound2_id': 48,
#   'constant_id': 32},
#  897: {'id': 897,
#   'rule_environment_id': 840,
#   'compound1_id': 49,
#   'compound2_id': 48,
#   'constant_id': 32},
#  898: {'id': 898,
#   'rule_environment_id': 841,
#   'compound1_id': 49,
#   'compound2_id': 48,
#   'constant_id': 32},
#  899: {'id': 899,
#   'rule_environment_id': 842,
#   'compound1_id': 49,
#   'compound2_id': 48,
#   'constant_id': 32},
#  900: {'id': 900,
#   'rule_environment_id': 843,
#   'compound1_id': 49,
#   'compound2_id': 48,
#   'constant_id': 32},
#  901: {'id': 901,
#   'rule_environment_id': 844,
#   'compound1_id': 50,
#   'compound2_id': 51,
#   'constant_id': 33},
#  902: {'id': 902,
#   'rule_environment_id': 845,
#   'compound1_id': 50,
#   'compound2_id': 51,
#   'constant_id': 33},
#  903: {'id': 903,
#   'rule_environment_id': 846,
#   'compound1_id': 50,
#   'compound2_id': 51,
#   'constant_id': 33},
#  904: {'id': 904,
#   'rule_environment_id': 847,
#   'compound1_id': 50,
#   'compound2_id': 51,
#   'constant_id': 33},
#  905: {'id': 905,
#   'rule_environment_id': 848,
#   'compound1_id': 50,
#   'compound2_id': 51,
#   'constant_id': 33},
#  906: {'id': 906,
#   'rule_environment_id': 849,
#   'compound1_id': 50,
#   'compound2_id': 51,
#   'constant_id': 33},
#  907: {'id': 907,
#   'rule_environment_id': 850,
#   'compound1_id': 52,
#   'compound2_id': 51,
#   'constant_id': 33},
#  908: {'id': 908,
#   'rule_environment_id': 851,
#   'compound1_id': 52,
#   'compound2_id': 51,
#   'constant_id': 33},
#  909: {'id': 909,
#   'rule_environment_id': 852,
#   'compound1_id': 52,
#   'compound2_id': 51,
#   'constant_id': 33},
#  910: {'id': 910,
#   'rule_environment_id': 853,
#   'compound1_id': 52,
#   'compound2_id': 51,
#   'constant_id': 33},
#  911: {'id': 911,
#   'rule_environment_id': 854,
#   'compound1_id': 52,
#   'compound2_id': 51,
#   'constant_id': 33},
#  912: {'id': 912,
#   'rule_environment_id': 855,
#   'compound1_id': 52,
#   'compound2_id': 51,
#   'constant_id': 33},
#  913: {'id': 913,
#   'rule_environment_id': 856,
#   'compound1_id': 51,
#   'compound2_id': 28,
#   'constant_id': 34},
#  914: {'id': 914,
#   'rule_environment_id': 857,
#   'compound1_id': 51,
#   'compound2_id': 28,
#   'constant_id': 34},
#  915: {'id': 915,
#   'rule_environment_id': 858,
#   'compound1_id': 51,
#   'compound2_id': 28,
#   'constant_id': 34},
#  916: {'id': 916,
#   'rule_environment_id': 859,
#   'compound1_id': 51,
#   'compound2_id': 28,
#   'constant_id': 34},
#  917: {'id': 917,
#   'rule_environment_id': 860,
#   'compound1_id': 51,
#   'compound2_id': 28,
#   'constant_id': 34},
#  918: {'id': 918,
#   'rule_environment_id': 861,
#   'compound1_id': 51,
#   'compound2_id': 28,
#   'constant_id': 34},
#  919: {'id': 919,
#   'rule_environment_id': 862,
#   'compound1_id': 51,
#   'compound2_id': 53,
#   'constant_id': 33},
#  920: {'id': 920,
#   'rule_environment_id': 863,
#   'compound1_id': 51,
#   'compound2_id': 53,
#   'constant_id': 33},
#  921: {'id': 921,
#   'rule_environment_id': 864,
#   'compound1_id': 51,
#   'compound2_id': 53,
#   'constant_id': 33},
#  922: {'id': 922,
#   'rule_environment_id': 865,
#   'compound1_id': 51,
#   'compound2_id': 53,
#   'constant_id': 33},
#  923: {'id': 923,
#   'rule_environment_id': 866,
#   'compound1_id': 51,
#   'compound2_id': 53,
#   'constant_id': 33},
#  924: {'id': 924,
#   'rule_environment_id': 867,
#   'compound1_id': 51,
#   'compound2_id': 53,
#   'constant_id': 33},
#  925: {'id': 925,
#   'rule_environment_id': 868,
#   'compound1_id': 51,
#   'compound2_id': 54,
#   'constant_id': 33},
#  926: {'id': 926,
#   'rule_environment_id': 869,
#   'compound1_id': 51,
#   'compound2_id': 54,
#   'constant_id': 33},
#  927: {'id': 927,
#   'rule_environment_id': 870,
#   'compound1_id': 51,
#   'compound2_id': 54,
#   'constant_id': 33},
#  928: {'id': 928,
#   'rule_environment_id': 871,
#   'compound1_id': 51,
#   'compound2_id': 54,
#   'constant_id': 33},
#  929: {'id': 929,
#   'rule_environment_id': 872,
#   'compound1_id': 51,
#   'compound2_id': 54,
#   'constant_id': 33},
#  930: {'id': 930,
#   'rule_environment_id': 873,
#   'compound1_id': 51,
#   'compound2_id': 54,
#   'constant_id': 33},
#  931: {'id': 931,
#   'rule_environment_id': 874,
#   'compound1_id': 27,
#   'compound2_id': 51,
#   'constant_id': 33},
#  932: {'id': 932,
#   'rule_environment_id': 875,
#   'compound1_id': 27,
#   'compound2_id': 51,
#   'constant_id': 33},
#  933: {'id': 933,
#   'rule_environment_id': 876,
#   'compound1_id': 27,
#   'compound2_id': 51,
#   'constant_id': 33},
#  934: {'id': 934,
#   'rule_environment_id': 877,
#   'compound1_id': 27,
#   'compound2_id': 51,
#   'constant_id': 33},
#  935: {'id': 935,
#   'rule_environment_id': 878,
#   'compound1_id': 27,
#   'compound2_id': 51,
#   'constant_id': 33},
#  936: {'id': 936,
#   'rule_environment_id': 879,
#   'compound1_id': 27,
#   'compound2_id': 51,
#   'constant_id': 33},
#  937: {'id': 937,
#   'rule_environment_id': 880,
#   'compound1_id': 51,
#   'compound2_id': 30,
#   'constant_id': 33},
#  938: {'id': 938,
#   'rule_environment_id': 881,
#   'compound1_id': 51,
#   'compound2_id': 30,
#   'constant_id': 33},
#  939: {'id': 939,
#   'rule_environment_id': 882,
#   'compound1_id': 51,
#   'compound2_id': 30,
#   'constant_id': 33},
#  940: {'id': 940,
#   'rule_environment_id': 883,
#   'compound1_id': 51,
#   'compound2_id': 30,
#   'constant_id': 33},
#  941: {'id': 941,
#   'rule_environment_id': 884,
#   'compound1_id': 51,
#   'compound2_id': 30,
#   'constant_id': 33},
#  942: {'id': 942,
#   'rule_environment_id': 885,
#   'compound1_id': 51,
#   'compound2_id': 30,
#   'constant_id': 33},
#  943: {'id': 943,
#   'rule_environment_id': 886,
#   'compound1_id': 51,
#   'compound2_id': 55,
#   'constant_id': 34},
#  944: {'id': 944,
#   'rule_environment_id': 887,
#   'compound1_id': 51,
#   'compound2_id': 55,
#   'constant_id': 34},
#  945: {'id': 945,
#   'rule_environment_id': 888,
#   'compound1_id': 51,
#   'compound2_id': 55,
#   'constant_id': 34},
#  946: {'id': 946,
#   'rule_environment_id': 889,
#   'compound1_id': 51,
#   'compound2_id': 55,
#   'constant_id': 34},
#  947: {'id': 947,
#   'rule_environment_id': 890,
#   'compound1_id': 51,
#   'compound2_id': 55,
#   'constant_id': 34},
#  948: {'id': 948,
#   'rule_environment_id': 891,
#   'compound1_id': 51,
#   'compound2_id': 55,
#   'constant_id': 34},
#  949: {'id': 949,
#   'rule_environment_id': 892,
#   'compound1_id': 51,
#   'compound2_id': 56,
#   'constant_id': 33},
#  950: {'id': 950,
#   'rule_environment_id': 893,
#   'compound1_id': 51,
#   'compound2_id': 56,
#   'constant_id': 33},
#  951: {'id': 951,
#   'rule_environment_id': 894,
#   'compound1_id': 51,
#   'compound2_id': 56,
#   'constant_id': 33},
#  952: {'id': 952,
#   'rule_environment_id': 895,
#   'compound1_id': 51,
#   'compound2_id': 56,
#   'constant_id': 33},
#  953: {'id': 953,
#   'rule_environment_id': 896,
#   'compound1_id': 51,
#   'compound2_id': 56,
#   'constant_id': 33},
#  954: {'id': 954,
#   'rule_environment_id': 897,
#   'compound1_id': 51,
#   'compound2_id': 56,
#   'constant_id': 33},
#  955: {'id': 955,
#   'rule_environment_id': 521,
#   'compound1_id': 50,
#   'compound2_id': 52,
#   'constant_id': 33},
#  956: {'id': 956,
#   'rule_environment_id': 809,
#   'compound1_id': 50,
#   'compound2_id': 52,
#   'constant_id': 33},
#  957: {'id': 957,
#   'rule_environment_id': 810,
#   'compound1_id': 50,
#   'compound2_id': 52,
#   'constant_id': 33},
#  958: {'id': 958,
#   'rule_environment_id': 898,
#   'compound1_id': 50,
#   'compound2_id': 52,
#   'constant_id': 33},
#  959: {'id': 959,
#   'rule_environment_id': 899,
#   'compound1_id': 50,
#   'compound2_id': 52,
#   'constant_id': 33},
#  960: {'id': 960,
#   'rule_environment_id': 900,
#   'compound1_id': 50,
#   'compound2_id': 52,
#   'constant_id': 33},
#  961: {'id': 961,
#   'rule_environment_id': 563,
#   'compound1_id': 50,
#   'compound2_id': 28,
#   'constant_id': 34},
#  962: {'id': 962,
#   'rule_environment_id': 901,
#   'compound1_id': 50,
#   'compound2_id': 28,
#   'constant_id': 34},
#  963: {'id': 963,
#   'rule_environment_id': 902,
#   'compound1_id': 50,
#   'compound2_id': 28,
#   'constant_id': 34},
#  964: {'id': 964,
#   'rule_environment_id': 903,
#   'compound1_id': 50,
#   'compound2_id': 28,
#   'constant_id': 34},
#  965: {'id': 965,
#   'rule_environment_id': 904,
#   'compound1_id': 50,
#   'compound2_id': 28,
#   'constant_id': 34},
#  966: {'id': 966,
#   'rule_environment_id': 905,
#   'compound1_id': 50,
#   'compound2_id': 28,
#   'constant_id': 34},
#  967: {'id': 967,
#   'rule_environment_id': 814,
#   'compound1_id': 50,
#   'compound2_id': 53,
#   'constant_id': 33},
#  968: {'id': 968,
#   'rule_environment_id': 815,
#   'compound1_id': 50,
#   'compound2_id': 53,
#   'constant_id': 33},
#  969: {'id': 969,
#   'rule_environment_id': 816,
#   'compound1_id': 50,
#   'compound2_id': 53,
#   'constant_id': 33},
#  970: {'id': 970,
#   'rule_environment_id': 906,
#   'compound1_id': 50,
#   'compound2_id': 53,
#   'constant_id': 33},
#  971: {'id': 971,
#   'rule_environment_id': 907,
#   'compound1_id': 50,
#   'compound2_id': 53,
#   'constant_id': 33},
#  972: {'id': 972,
#   'rule_environment_id': 908,
#   'compound1_id': 50,
#   'compound2_id': 53,
#   'constant_id': 33},
#  973: {'id': 973,
#   'rule_environment_id': 820,
#   'compound1_id': 50,
#   'compound2_id': 54,
#   'constant_id': 33},
#  974: {'id': 974,
#   'rule_environment_id': 821,
#   'compound1_id': 50,
#   'compound2_id': 54,
#   'constant_id': 33},
#  975: {'id': 975,
#   'rule_environment_id': 822,
#   'compound1_id': 50,
#   'compound2_id': 54,
#   'constant_id': 33},
#  976: {'id': 976,
#   'rule_environment_id': 909,
#   'compound1_id': 50,
#   'compound2_id': 54,
#   'constant_id': 33},
#  977: {'id': 977,
#   'rule_environment_id': 910,
#   'compound1_id': 50,
#   'compound2_id': 54,
#   'constant_id': 33},
#  978: {'id': 978,
#   'rule_environment_id': 911,
#   'compound1_id': 50,
#   'compound2_id': 54,
#   'constant_id': 33},
#  979: {'id': 979,
#   'rule_environment_id': 912,
#   'compound1_id': 27,
#   'compound2_id': 50,
#   'constant_id': 33},
#  980: {'id': 980,
#   'rule_environment_id': 913,
#   'compound1_id': 27,
#   'compound2_id': 50,
#   'constant_id': 33},
#  981: {'id': 981,
#   'rule_environment_id': 914,
#   'compound1_id': 27,
#   'compound2_id': 50,
#   'constant_id': 33},
#  982: {'id': 982,
#   'rule_environment_id': 915,
#   'compound1_id': 27,
#   'compound2_id': 50,
#   'constant_id': 33},
#  983: {'id': 983,
#   'rule_environment_id': 916,
#   'compound1_id': 27,
#   'compound2_id': 50,
#   'constant_id': 33},
#  984: {'id': 984,
#   'rule_environment_id': 917,
#   'compound1_id': 27,
#   'compound2_id': 50,
#   'constant_id': 33},
#  985: {'id': 985,
#   'rule_environment_id': 918,
#   'compound1_id': 50,
#   'compound2_id': 30,
#   'constant_id': 33},
#  986: {'id': 986,
#   'rule_environment_id': 919,
#   'compound1_id': 50,
#   'compound2_id': 30,
#   'constant_id': 33},
#  987: {'id': 987,
#   'rule_environment_id': 920,
#   'compound1_id': 50,
#   'compound2_id': 30,
#   'constant_id': 33},
#  988: {'id': 988,
#   'rule_environment_id': 921,
#   'compound1_id': 50,
#   'compound2_id': 30,
#   'constant_id': 33},
#  989: {'id': 989,
#   'rule_environment_id': 922,
#   'compound1_id': 50,
#   'compound2_id': 30,
#   'constant_id': 33},
#  990: {'id': 990,
#   'rule_environment_id': 923,
#   'compound1_id': 50,
#   'compound2_id': 30,
#   'constant_id': 33},
#  991: {'id': 991,
#   'rule_environment_id': 924,
#   'compound1_id': 50,
#   'compound2_id': 55,
#   'constant_id': 34},
#  992: {'id': 992,
#   'rule_environment_id': 925,
#   'compound1_id': 50,
#   'compound2_id': 55,
#   'constant_id': 34},
#  993: {'id': 993,
#   'rule_environment_id': 926,
#   'compound1_id': 50,
#   'compound2_id': 55,
#   'constant_id': 34},
#  994: {'id': 994,
#   'rule_environment_id': 927,
#   'compound1_id': 50,
#   'compound2_id': 55,
#   'constant_id': 34},
#  995: {'id': 995,
#   'rule_environment_id': 928,
#   'compound1_id': 50,
#   'compound2_id': 55,
#   'constant_id': 34},
#  996: {'id': 996,
#   'rule_environment_id': 929,
#   'compound1_id': 50,
#   'compound2_id': 55,
#   'constant_id': 34},
#  997: {'id': 997,
#   'rule_environment_id': 930,
#   'compound1_id': 50,
#   'compound2_id': 56,
#   'constant_id': 33},
#  998: {'id': 998,
#   'rule_environment_id': 931,
#   'compound1_id': 50,
#   'compound2_id': 56,
#   'constant_id': 33},
#  999: {'id': 999,
#   'rule_environment_id': 932,
#   'compound1_id': 50,
#   'compound2_id': 56,
#   'constant_id': 33},
#  1000: {'id': 1000,
#   'rule_environment_id': 933,
#   'compound1_id': 50,
#   'compound2_id': 56,
#   'constant_id': 33},
#  ...}

# %%
dataTable_pair
# Out:
#          pair_id  rule_environment_id  compound1_id  compound2_id  constant_id
# 1              1                    1             1             2            1
# 2              2                    2             1             2            1
# 3              3                    3             1             2            1
# 4              4                    4             1             2            1
# 5              5                    5             1             2            1
# ...          ...                  ...           ...           ...          ...
# 1562822  1562822               733663          5487          8266        18769
# 1562823  1562823              1350235          5487          8266        18769
# 1562824  1562824              1350367          5487          8266        18769
# 1562825  1562825              1350368          5487          8266        18769
# 1562826  1562826              1350369          5487          8266        18769
#
# [1562826 rows x 5 columns]

# %%
for i in dataDict_dicts["rule_environment"]:
    if i != dataDict_dicts["rule_environment"][i]['id']:
        print(i, dataDict_dicts["rule_environment"][i]['id'])

# %%
for i in dataDict_dicts["compound"]:
    if i != dataDict_dicts["compound"][i]['id']:
        print(i, dataDict_dicts["compound"][i]['id'])

# %%
for i in dataDict_dicts["rule"]:
    if i != dataDict_dicts["rule"][i]['id']:
        print(i, dataDict_dicts["rule"][i]['id'])

# %%
for i in dataDict_dicts["property_name"]:
    if i != dataDict_dicts["property_name"][i]['id']:
        print(i, dataDict_dicts["property_name"][i]['id'])

# %%
for i in dataDict_dicts["constant_smiles"]:
    if i != dataDict_dicts["constant_smiles"][i]['id']:
        print(i, dataDict_dicts["constant_smiles"][i]['id'])

# %%
dataTable_pair = dataDict_tables["pair"].rename(columns={'id': 'pair_id'})
print(dataTable_pair.shape)
dataTable_pair.head(3)

# %%
pair_dict = {}
for p_idx in dataTable_pair.index:
    pid = dataTable_pair['pair_id'][p_idx]
    cid_1 = dataTable_pair['compound1_id'][p_idx]
    cid_2 = dataTable_pair['compound2_id'][p_idx]
    csid = dataTable_pair['constant_id'][p_idx]
    reid = dataTable_pair['rule_environment_id'][p_idx]

    pair_set = f'{sorted([cid_1, cid_2])[0]}<=>{sorted([cid_1, cid_2])[1]}'
    if pair_set not in pair_dict:
        pair_dict[pair_set] = {}
    
    pair_trans = f"{cid_1}=>{cid_2}"
    if pair_trans not in pair_dict[pair_set]:
        pair_dict[pair_set][pair_trans] = {}

    pair_dict[pair_set][pair_trans][pid] = {}
    pair_dict[pair_set][pair_trans][pid]['pair_id'] = pid
    pair_dict[pair_set][pair_trans][pid]['constant_id'] = csid
    pair_dict[pair_set][pair_trans][pid]['rule_environment_id'] = reid
    pair_dict[pair_set][f"num_pairs_{pair_trans}"] = len(pair_dict[pair_set][pair_trans])

# %%
len(pair_dict)

# %%
pd.DataFrame.from_dict(pair_dict).T

# %%
pair_dict

# %%
dataTable_pair = dataDict_tables["pair"].rename(columns={'id': 'pair_id'})
print(dataTable_pair.shape)
print(len(dataTable_pair['rule_environment_id'].unique()))

dataTable_rule_env = dataDict_tables["rule_environment"].rename(columns={'id': 'rule_environment_id'})
print(dataTable_rule_env.shape)
print(len(dataTable_rule_env['rule_environment_id'].unique()))

dataTable = pd.merge(left=dataTable_pair, right=dataTable_rule_env, on='rule_environment_id')
print(dataTable.shape)
print(len(dataTable['rule_environment_id'].unique()))
dataTable.head(3)

# %%
print(len(dataTable_pair['compound1_id'].unique()))

# %%
print(len(dataTable_pair['compound2_id'].unique()))

# %%
dataTable['radius'].value_counts()

# %%
dataTable_rule_env['radius'].value_counts()

# %%
dataTable_pair['pair_couple'] =

# %%
for r in range(6):
    dataTable_rule_env_r = dataTable_rule_env[dataTable_rule_env['radius']==r]
    print(r, dataTable_rule_env_r.shape)

# %%
dataTable_rule_env = dataDict_tables["rule_environment"]
print(dataTable_rule_env.shape)
dataTable_rule_env.head(3)

# %%
dataTable_rule_env[dataTable_rule_env['radius']==1]

# %%
dataTable_rule_env[dataTable_rule_env['radius']==0]

# %%
dataTable_rule = dataDict_tables["rule"]
print(dataTable_rule.shape)
dataTable_rule.head(3)

# %%
dataTable = copy.deepcopy(dataDict_tables["pair"])
print("raw:", dataTable.shape)

## ------------------- add compound structure & property data -------------------

# %%
dataTable = copy.deepcopy(dataDict_tables["pair"])
print("raw:", dataTable.shape)

## ------------------- add compound structure & property data -------------------
table_merge = dataDict_tables["compound"]

## compound-1 (from)
dataTable = dataTable.merge(table_merge, left_on=['compound1_id'], right_on=['id'])
dataTable.drop(columns=['id_y', 'clean_smiles', 'clean_num_heavies'], inplace=True)
dataTable.rename(columns={'id_x':'id', 'public_id':'KT_number_1', 'input_smiles':'smiles_1'}, inplace=True)

## compound-2 (to)
dataTable = dataTable.merge(table_merge, left_on=['compound2_id'], right_on=['id'])
dataTable.drop(columns=['id_y', 'clean_smiles', 'clean_num_heavies'], inplace=True)
dataTable.rename(columns={'id_x':'id', 'public_id':'KT_number_2', 'input_smiles':'smiles_2'}, inplace=True)
print("join cmpd smi:", dataTable.shape)

## ------------------- add compound prop data -------------------
table_merge = dataDict_tables["compound_property"]

## compound-1 (from)
dataTable = dataTable.merge(table_merge, left_on=['compound1_id'], right_on=['compound_id'])
dataTable.drop(columns=['id_y', 'compound_id'], inplace=True)
dataTable.rename(columns={'id_x':'id', 'value':'property_values_1'}, inplace=True)

## compound-2 (to)
dataTable = dataTable.merge(table_merge, left_on=['compound2_id', 'property_name_id'], right_on=['compound_id', 'property_name_id'])
dataTable.drop(columns=['id_y', 'compound_id'], inplace=True)
dataTable.rename(columns={'id_x':'id', 'value':'property_values_2'}, inplace=True)

## add property name
table_merge = dataDict_tables["property_name"]
dataTable = dataTable.merge(table_merge, left_on=['property_name_id'], right_on=['id'])
dataTable.drop(columns=['id_y'], inplace=True)
dataTable.rename(columns={'id_x':'id', 'name':'property_name'}, inplace=True)
print("join cmpd prop:", dataTable.shape)

## ------------------- add constant pieces data of the match pair -------------------
table_merge = dataDict_tables["constant_smiles"]
dataTable = dataTable.merge(table_merge, left_on=['constant_id'], right_on=['id'])
dataTable.drop(columns=['id_y'], inplace=True)
dataTable.rename(columns={'id_x':'id', 'smiles':'constant_smiles'}, inplace=True)
print("join constant smi:", dataTable.shape)

## ------------------- add rule env data -------------------
table_merge = dataDict_tables["rule_environment"]
dataTable = dataTable.merge(table_merge, left_on=['rule_environment_id'], right_on=['id'])
dataTable.drop(columns=['id_y'], inplace=True)
dataTable.rename(columns={'id_x':'id', 'radius':'rule_env_radius', 'num_pairs':'rule_env_num_pairs'}, inplace=True)
print("join rule env:", dataTable.shape)

## ------------------- add rule info -------------------
table_merge = dataDict_tables["rule"]
dataTable = dataTable.merge(table_merge, left_on=['rule_id'], right_on=['id'])
dataTable.drop(columns=['id_y'], inplace=True)    #'rule_id'
dataTable.rename(columns={'id_x':'id'}, inplace=True)

table_merge = dataDict_tables["rule_smiles"]
dataTable = dataTable.merge(table_merge, left_on=['from_smiles_id'], right_on=['id'])
dataTable.drop(columns=['id_y', 'from_smiles_id', 'num_heavies'], inplace=True)    #'num_heavies'
dataTable.rename(columns={'id_x':'id', 'smiles':'rule_from_smiles'}, inplace=True)

table_merge = dataDict_tables["rule_smiles"]
dataTable = dataTable.merge(table_merge, left_on=['to_smiles_id'], right_on=['id'])
dataTable.drop(columns=['id_y', 'to_smiles_id', 'num_heavies'], inplace=True)
dataTable.rename(columns={'id_x':'id', 'smiles':'rule_to_smiles'}, inplace=True)
print("join rule:", dataTable.shape)

## ------------------- add rule env stats -------------------
table_merge = dataDict_tables["rule_environment_statistics"]
dataTable = dataTable.merge(table_merge, 
                            left_on=['rule_environment_id', 'property_name_id'], 
                            right_on=['rule_environment_id', 'property_name_id'])

drop_cols = ['kurtosis', 'skewness', 'paired_t', 'p_value', 'q1', 'q3', 'median', 'std']
dataTable.drop(columns=['id_y']+drop_cols, inplace=True)
dataTable.rename(columns={'id_x':'id', 'count':'rule_env_count', 'avg':'rule_env_avg', 
                          'min':'rule_env_min', 'max':'rule_env_max'}, inplace=True)

print("join rule stats:", dataTable.shape)
## ------------------- add rule env environment_fingerprint data -------------------
table_merge = dataDict_tables["environment_fingerprint"]
## to be added

## ------------------- remove useless cols -------------------
dataTable.drop(columns=['id', 'compound1_id', 'compound2_id', 'constant_id', 'rule_environment_id', 'property_name_id'], inplace=True)
print(dataTable.shape)
dataTable.head(3)

# %%
pair_dict = {}

for idx in dataTable_pair.index:
    cidx_1 = dataTable_pair['compound1_id'][idx]
    cidx_2 = dataTable_pair['compound2_id'][idx]
    pair_idx = '<=>'.join(sorted([cidx_1, cidx_2]))
    if pair_idx not in pair_dict:
        pair_dict[pair_idx] = {}

        

    pair_dict[pair_idx][idx] = {}
    pair_dict[pair_idx][idx]['c1_id'] = cidx_1
    pair_dict[pair_idx][idx]['c2_id'] = cidx_2
    pair_dict[pair_idx][idx]['c2_id'] = cidx_2

# %% [markdown]
# #### 1. Read the entire DB

# %%
dataTable = pd.read_csv(f'./results/Compounds_All_4_informatics.csv')
print(dataTable.shape)
dataTable.head(3)

# %%
## duplicate all redius < 0 data
dataTable_radiu0 = dataTable[dataTable['rule_env_radius']==0].reset_index(drop=True)
print(dataTable_radiu0.shape)
dataTable_radiu0.head(3)

# %%
## collect the stats of the max const size
dataDict_max_const = {}
dataTable_loop = dataTable_radiu0

for idx in dataTable_loop.index:
    KT_id_1, KT_id_2 = dataTable_loop['KT_number_1'][idx], dataTable_loop['KT_number_2'][idx]
    
    pair_idx = '<=>'.join(sorted([KT_id_1, KT_id_2]))
    ## initialize the pair idx
    if pair_idx not in dataDict_max_const:
        dataDict_max_const[pair_idx] = {}
        dataDict_max_const[pair_idx]['pair_idx'] = pair_idx
        dataDict_max_const[pair_idx]['max_constant_size'] = 0

    ## update the max const size
    constant_size =  dataTable_loop['constant_size'][idx]
    if constant_size > dataDict_max_const[pair_idx]['max_constant_size']:
        dataDict_max_const[pair_idx]['max_constant_size'] = constant_size

# %%
def keep_row(row, dataDict_stats):
    KT_id_1 = row['KT_number_1'] 
    KT_id_2 = row['KT_number_2']
    constant_size = row['constant_size']
    ## exam whether the constant size in this row match the max size
    pair_idx = '<=>'.join(sorted([KT_id_1, KT_id_2]))
    assert pair_idx in dataDict_stats, f"Error! This pair {pair_idx} is not in the data"
    constant_size_max = dataDict_stats[pair_idx]['max_constant_size']
    ## export results
    if constant_size >= constant_size_max:
        if_keep = 1
    else:
        if_keep = 0
    return pd.Series([pair_idx, if_keep])

dataTable_radiu0[['pair_idx', 'Keep_row']] = dataTable_radiu0.apply(lambda row: keep_row(row, dataDict_max_const), axis=1)
print(dataTable_radiu0.shape)
dataTable_radiu0.head(3)

# %%
dataTable_clean = dataTable_radiu0[dataTable_radiu0['Keep_row']==1].sort_values(by=['pair_idx', 'KT_number_1', 'KT_number_2'])
dataTable_clean

# %%
dataTable_clean['pair_idx'].value_counts()

# %%
len(list(dataTable_clean['pair_idx'].unique()))

# %%
dataTable_clean[dataTable_clean['pair_idx']=='KT-0036156<=>KT-0036845']

# %%
dataDict_clean = {}
dataTable_loop = dataTable_radiu0

for idx in dataTable_loop.index:
    KT_id_1, KT_id_2 = dataTable_loop['KT_number_1'][idx], dataTable_loop['KT_number_2'][idx]

# %%
for prop in dataTable_radiu0['property_name'].unique():
    print(f"============================= {prop} =============================")
    dataTable_prop = dataTable_radiu0[dataTable_radiu0['property_name']==prop]
    print(f"Num of rows is {dataTable_prop.shape[0]}")

    list_cid_1 = dataTable_prop['KT_number_1'].unique()
    list_cid_2 = dataTable_prop['KT_number_2'].unique()
    print(len(list_cid_1), len(list_cid_2))
    print(len(set(list_cid_1) & set(list_cid_2)))
    print(len([id for id in list_cid_1 if id not in list_cid_2]))
    print(len([id for id in list_cid_2 if id not in list_cid_1]))

# %%
dataDict_clean = {}

for idx in dataTable_radiu0.index():
    KT_id_1, KT_id_2 = dataTable_radiu0['KT_number_1'][idx], dataTable_radiu0['KT_number_2'][idx]

    pair_idx = '<=>'.join(sorted([KT_id_1, KT_id_2]))
    if pair_idx not in dataDict_clean:
        dataDict_clean[pair_idx] = {}
        dataDict_clean[pair_idx]['constant_size_max'] = 0
        dataDict_clean[pair_idx]['row_idx'] = []

    constant_size =  dataTable_radiu0['constant_size'][idx]

    
    
    dataDict_clean[pair_idx]['KT_number_1'] = KT_id_1
    dataDict_clean[pair_idx]['KT_number_1'] = KT_id_2

    dataDict_clean[pair_idx]['smiles_1'] = dataTable_radiu0['smiles_1'][idx]
    dataDict_clean[pair_idx]['smiles_2'] = dataTable_radiu0['smiles_2'][idx]
    


        for col in []:
            dataDict_clean[pair_id][col] = dataTable_radiu0[col][idx]

# %%
################################################################################################
## generate "pair id" for each pairs
def GeneratePairID(row, col_mol_id_1='KT_number_1', col_mol_id_2='KT_number_2'):
    mol_id_1 = row[col_mol_id_1]
    mol_id_2 = row[col_mol_id_2]
    pair_id = str(mol_id_1) + '=>' + str(mol_id_2)
    
    mol_id_1_num = int(str(mol_id_1).split('-')[1])
    mol_id_2_num = int(str(mol_id_2).split('-')[1])
    pair_couple = (np.min([mol_id_1_num, mol_id_2_num]), np.max([mol_id_1_num, mol_id_2_num]))
    return pd.Series([pair_id, pair_couple])

dataTable[['Pair_id', 'PairInfo']] = dataTable.apply(lambda row: GeneratePairID(row, col_mol_id_1='KT_number_1', col_mol_id_2='KT_number_2'), axis=1)
print(dataTable.shape)

################################################################################################

################################################################################################

# %%
# # dataTable.to_csv(f'./results/Compounds_All_4_informatics.csv', index=False)
# dataTable = pd.read_csv(f'./results/Compounds_All_4_informatics.csv')
# print(dataTable.shape)
# dataTable.head(3)

# %% [markdown]
# #### 3. removed the "duplicated" rows

# %%
## duplicate all rows with reversed data
dataTable_radiu0 = dataTable[dataTable['rule_env_radius']==0].reset_index(drop=True)
dataTable_radiu0['rvs'] = 0
print(dataTable_radiu0.shape)

# %%
## duplicate all rows with reversed data
dataTable_radiu0 = dataTable[dataTable['rule_env_radius']==0].reset_index(drop=True)
dataTable_radiu0['rvs'] = 0
print(dataTable_radiu0.shape)


dict_reverse_cols = {'KT_number_1': 'KT_number_2', 'smiles_1': 'smiles_2', 'property_values_1': 'property_values_2',
                     'KT_number_2': 'KT_number_1', 'smiles_2': 'smiles_1', 'property_values_2': 'property_values_1',
                     'rule_from_smiles': 'rule_to_smiles', 'rule_to_smiles': 'rule_from_smiles'}
dataTable_radiu0_reverse = dataTable_radiu0.rename(columns=dict_reverse_cols)
dataTable_radiu0_reverse['rvs'] = 1
print(dataTable_radiu0_reverse.shape)

dataTable_radiu0_dups = pd.concat([dataTable_radiu0, dataTable_radiu0_reverse], ignore_index=True)
dataTable_radiu0_dups = dataTable_radiu0_dups.sort_values(by=['PairInfo', 'property_name', 'constant_size', 'constant_smiles', 'rvs'], 
                                                          ascending=[True, True, False, True, True])
print(dataTable_radiu0_dups.shape)

# %%
## only keep the pairs with max constant structure 
dataTable_radiu0_rmdups = dataTable_radiu0_dups.drop_duplicates(subset=['KT_number_1', 'KT_number_2', 'property_name', 'constant_smiles', 'rule_from_smiles', 'rule_to_smiles'])
dataTable_radiu0_rmdups = dataTable_radiu0_rmdups.reset_index(drop=True)
print(dataTable_radiu0_rmdups.shape)
dataTable_radiu0_rmdups.head(3)

# %%
list_dataTable_sele = []
for pi in dataTable_radiu0_rmdups['PairInfo'].unique():
    dataTable_subset = dataTable_radiu0_rmdups[dataTable_radiu0_rmdups['PairInfo']==pi]
    dataTable_sele = dataTable_subset[dataTable_subset['constant_size']==dataTable_subset['constant_size'].max()]
    list_dataTable_sele.append(dataTable_sele)

dataTable_clean = pd.concat(list_dataTable_sele)
print(dataTable_clean.shape)
dataTable_clean.head(3)

# %%
dataTable_radiu0_dups.to_csv(f'./results/Tmp_Compounds_All_4_informatics_dups.csv', index=False)

# %%
dataDict_mmps = {}

## loop all property
for prop in dataTable_radiu0['property_name'].unique():
    ## get all available data with this property in this cid-set
    dataTable_prop = dataTable_radiu0[dataTable_radiu0['property_name']==prop]
    print('====================', prop, ':', dataTable_prop.shape[0], '====================')

    ## loop all cid-sets
    for cid_set in dataTable_prop['PairInfo'].unique():
        ## get all available data with this cid-set
        dataTable_prop_pair = dataTable_prop[dataTable_prop['PairInfo']==cid_set]
        
        ## get pair compound id 
        cid_1, cid_2 = f"KT-{cid_set[0]:07}", f"KT-{cid_set[1]:07}"
        pair_id_a, pair_id_b = f"{cid_1}=>{cid_2}", f"{cid_2}=>{cid_1}"

        num_fragmentations = dataTable_prop_pair['constant_smiles'].unique()

# %%
dataTable_radiu0 = dataTable[dataTable['rule_env_radius']==0].reset_index(drop=True)
print(dataTable_radiu0.shape)

dataDict_mmps = {}

## loop all property
for prop in dataTable_radiu0['property_name'].unique():
    ## get all available data with this property in this cid-set
    dataTable_prop = dataTable_radiu0[dataTable_radiu0['property_name']==prop]
    print(prop, ':', dataTable_prop.shape[0])

    ## loop all cid-sets
    for cid_set in dataTable_prop['PairInfo'].unique():
        ## get pair compound id 
        cid_1, cid_2 = f"KT-{cid_set[0]:07}", f"KT-{cid_set[1]:07}"
        pair_id_a, pair_id_b = f"{cid_1}=>{cid_2}", f"{cid_2}=>{cid_1}"

        ## get all available data with this cid-set
        dataTable_prop_pair = dataTable_prop[dataTable_prop['PairInfo']==cid_set]
        num_fragmentations = dataTable_prop_pair['constant_smiles'].unique()

        for const_smi in dataTable_prop_pair['constant_smiles'].unique():
            const_smi_list = const_smi.split('.')


            dataTable_prop_pair_cuts = dataTable_prop_pair[dataTable_prop_pair['constant_smiles']==const_smi]
            if dataTable_prop_pair_cuts.shape[0] > 2:
                print(prop, cid_1, cid_2, dataTable_prop_pair_cuts.shape[0])
                test_dataTable = dataTable_prop_pair_cuts

               
        # dataTable_prop_pair = dataTable_prop_pair.sort_values(by=['constant_size', 'Pair_id'], ascending=[False, True], inplace=False)
        
        # if dataTable_prop_pair.shape[0] > 2:
        #     print(prop, cid_1, cid_2, dataTable_prop_pair.shape[0])

        # ## if this pair-a is available
        # if pair_id_a in dataTable_prop_pair['Pair_id'].unique():
        #     dataTable_prop_pair_a = dataTable_prop_pair[dataTable_prop_pair['Pair_id']==pair_id_a]
        #     dataTable_prop_pair_a

                    

        #     pass
        # else:
        #     pass
        
        # ## if this pair-b is available
        # if pair_id_b in dataTable_prop_pair['Pair_id'].unique():
        #     dataTable_prop_pair_b = dataTable_prop_pair[dataTable_prop_pair['Pair_id']==pair_id_b]
        #     pass
        # else:
        #     pass

# %%
dataTable_prop[(dataTable_prop['Pair_id']=='KT-0000058=>KT-0014349')]

# %%
test_dataTable['constant_smiles'][265].split('.')[0]

# %%
calculate_heavy_atoms(test_dataTable['constant_smiles'][265].split('.')[0])

# %%
Chem.MolFromSmiles(test_dataTable['constant_smiles'][265].split('.')[0]).

# %%
test_dataTable

# %%
unique_cid_1 = dataTable_radiu0['KT_number_1'].unique()
print(len(unique_cid_1))

unique_cid_2 = dataTable_radiu0['KT_number_2'].unique()
print(len(unique_cid_2))

unique_pair_set = dataTable_radiu0['PairInfo'].unique()
print(len(unique_pair_set))

# %%
f"KT-{unique_pair_set[0][0]:07}" in unique_cid_1

# %%
7990-4500-2677

# %%
dataDict_mmps = {}


for idx in dataTable_radiu0.index:
    pair_info = dataTable_radiu0['PairInfo'][idx]
    pair_id = dataTable_radiu0['Pair_id'][idx]
    cid_1, cid_2 = dataTable_radiu0['KT_number_1'][idx], dataTable_radiu0['KT_number_2'][idx]
    
    if pair_info not in dataDict_mmps

# %%
dataTable_radiu0 = dataTable[dataTable['rule_env_radius']==0].reset_index(drop=True)
print(dataTable_radiu0.shape)

dataTable_radiu0 = dataTable_radiu0.sort_values(by=['PairInfo', 'Pair_id', 'property_name', 'rule_env_radius', 'constant_size'], ascending=[True, True, False], inplace=False)
dataTable_rmDup = dataTable_radiu0.drop_duplicates(subset=['PairInfo', 'property_name'], keep='first', inplace=False)
dataTable_rmDup.to_csv(f'./results/Compounds_All_4_informatics_rmDups_raw.csv', index=False)
print(dataTable_rmDup.shape)
dataTable_rmDup.head(3)

# %% [markdown]
# #### append symetric rows

# %%
dataTable_rmDup

# %%
rename_symetric_dict = {
    'KT_number_1': 'KT_number_2',
    'smiles_1': 'smiles_2',
    'KT_number_2': 'KT_number_1',
    'smiles_2': 'smiles_1',
    'property_values_1': 'property_values_2',
    'property_values_2': 'property_values_1', 
    'rule_from_smiles': 'rule_to_smiles',
    'rule_to_smiles': 'rule_from_smiles'}
dataTable_rmDup_symetric = dataTable_rmDup.rename(columns=rename_symetric_dict, inplace=False)
dataTable_rmDup_symetric['Pair_id'] = dataTable_rmDup_symetric['KT_number_1'] + '=>' + dataTable_rmDup_symetric['KT_number_2']
for col in ['rule_env_avg', 'rule_env_min', 'rule_env_max']:
    dataTable_rmDup_symetric[col] = dataTable_rmDup_symetric[col] * -1
dataTable_rmDup_symetric.head(3)

# %%
dataTable_rmDup_all = dataTable_rmDup._append(dataTable_rmDup_symetric, ignore_index=True)
dataTable_rmDup_all['rule_env_min'] = dataTable_rmDup_all['rule_env_min'].apply(lambda x:round(x, 2)).astype('str')
dataTable_rmDup_all['rule_env_max'] = dataTable_rmDup_all['rule_env_max'].apply(lambda x:round(x, 2)).astype('str')
dataTable_rmDup_all['rule_env_range'] = '('+ dataTable_rmDup_all['rule_env_min'] + ',' + dataTable_rmDup_all['rule_env_max'] +')'

# %%
dataTable_rmDup_all.sort_values(by=['PairInfo', 'property_name', 'Pair_id'], ascending=[True, True, True], inplace=True)
dataTable_rmDup_all = dataTable_rmDup_all.reset_index(drop=True)
dataTable_rmDup_all

# %%
dataTable_rmDup_all.to_csv(f'./results/Compounds_All_4_informatics_rmDups.csv', index=False)
