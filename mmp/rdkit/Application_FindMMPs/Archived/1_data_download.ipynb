# %%
import warnings
warnings.filterwarnings('ignore')

import os
import time

import pandas as pd

from d360api import d360api

# %%
##--------------------------------------------------------------
def dataDownload(my_query_id=2905, user_name="yjing@kymeratx.com", tokenFile='yjing_D360.token'):
    # Create API connection to the PROD server
    my_d360 = d360api(provider="https://10.3.20.47:8080")  # PROD environment
    user_name = user_name
    tokenFile = tokenFile
    
    with open(tokenFile, 'r') as ofh:
        service_token = ofh.readlines()[0]

    # Authenticate connection using service token
    my_d360.authenticate_servicetoken(servicetoken=service_token, user=user_name)
    results = my_d360.download_query_results(query_id=my_query_id)
    return results

##--------------------------------------------------------------
def loadCSV(dataTableFileName):
    try:
        dataTable = pd.read_csv(dataTableFileName)
    except Exception as e:
        print(f'Error: cannot read output file {dataTableFileName}; error msg: {e}')
        dataTable = None
    else:
        dataTable = dataTable.reset_index(drop=True)
        print(f'The downloaded data have data shape {dataTable.shape}')
    return dataTable

# %%
my_query_id = 3539 # 2905

## download data from D360 using API
dataTableFileName = dataDownload(my_query_id=my_query_id)
print(f'All data have been downloaded in file {dataTableFileName}')
# Out:
# Query with request id 22b0cae3-a2c7-47e5-9b7b-b764a0c40d2a initiated
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# RUNNING
# SUCCESS
# Query results saved in file D360_dataset_q_id3539_280824_0045.csv
# All data have been downloaded in file D360_dataset_q_id3539_280824_0045.csv

# %%
## extract data from downloaded file
dataTable = loadCSV(dataTableFileName)
dataTable.head(3)
# Out:
# The downloaded data have data shape (25714, 40)
#   Compound Name                                          Structure  \
# 0    KT-0026812  C[C@@H]%10CNc2c(sc3ccc1nc(ccc1c32)-c4ccc(cc4)N...
# 1    KT-0026813  CN2C(=O)N(C1CCC(=O)NC1=O)c3cccc(c32)N%10CCC(CN...
# 2    KT-0026814  Fc1c(cccc1)-c5nc4c(c2c(sc3c2NC[C@H](NC3=O)C)cc...
#
#                                               Smiles Concat;Project  \
# 0  C[C@@H]1CNC2=C(SC3=CC=C4N=C(C5=CC=C(N6CCC(CN7C...            MK2
# 1  CN1C(=O)N(C2CCC(=O)NC2=O)C2=CC=CC(N3CCC(CN4CCC...            MK2
# 2  N1C(=O)C2=C(C3=C(C=CC4=NC(C5=CC=CC=C5F)=CC=C43...            MK2
#
#   Concat;External Id   Created On    Log D  \
# 0       MK2-361-001F  12-Aug-2021  5.59691
# 1       MK2-367-001N  12-Aug-2021  2.20623
# 2       MK2-368-001H  12-Aug-2021  3.83864
#
#   ADME MDCK(WT) Permeability;Mean;A to B Papp (10^-6 cm/s);(Mod)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ADME MDCK(WT) Permeability;Mean;A to B Papp (10^-6 cm/s);(Num)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   ADME MDCK(WT) Permeability;Mean;B to A Papp (10^-6 cm/s);(Mod)  ...  \
# 0                                                NaN              ...
# 1                                                NaN              ...
# 2                                                NaN              ...
#
#    ADME Tox-manual patch hERG 34C;Mean;Average % of hERG inhibition;(Num)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   ADME Tox-manual patch hERG 34C;Concat;Comments  \
# 0                      17.94% inhibition @ 10 ?M
# 1                                            NaN
# 2                                            NaN
#
#   ADME Tox-manual patch hERG 34C;Mean;Concentration (uM);(Mod)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ADME Tox-manual patch hERG 34C;Mean;Concentration (uM);(Num)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ADME Tox-manual patch hERG 34C;Concat;Date run  \
# 0                                      11/17/2022
# 1                                             NaN
# 2                                             NaN
#
#   ADME Tox-manual patch hERG 34C;GMean;m-patch hERG IC50 [uM];(Mod)  \
# 0                                                  >
# 1                                                NaN
# 2                                                NaN
#
#    ADME Tox-manual patch hERG 34C;GMean;m-patch hERG IC50 [uM];(Num)  \
# 0                                               10.0
# 1                                                NaN
# 2                                                NaN
#
#   ADME Tox-manual patch hERG 34C;Mean;SD;(Mod)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
#    ADME Tox-manual patch hERG 34C;Mean;SD;(Num)    Marked
# 0                                           NaN  UNMARKED
# 1                                           NaN  UNMARKED
# 2                                           NaN  UNMARKED
#
# [3 rows x 40 columns]
